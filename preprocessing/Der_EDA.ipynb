# %%
# Numerical Operations
import math
import numpy as np

# Reading/Writing Data
import pandas as pd
import os
import csv

# For Progress Bar
from tqdm import tqdm

# Pytorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split

# For plotting learning curve
#from torch.utils.tensorboard import SummaryWriter

#Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import pairwise_distances
from sklearn.cluster import KMeans


import os

# %%
pd.set_option('display.max_columns', None)
#pd.reset_option('display.max_columns')

# %%
current_dir = os.getcwd()
parent_dir  = os.path.dirname(current_dir)
public  = pd.read_csv(parent_dir + r'/datasets/public_processed.csv') #,usecols=lambda column: column != 'txkey')
train   = pd.read_csv(parent_dir + r'/datasets/training.csv') #,usecols=lambda column: column != 'txkey')

# %%
df = pd.concat([public,train])

# %%
del public, train

# %%
df = df.fillna(-1)
df.head(10)
# Out:
#                                                txkey  locdt   loctm  \
# 0  a2c1209018e4e52e04f6fabb48f05f1b8bc09dc838ff6c...     56  105157
# 1  16c4880500059e01553789be11bbb50753b7acaae7b95b...     56  185520
# 2  623c56be3bee87724e3d119c271d9ed098eeda84233183...     59  102312
# 3  250da12187059cf6e3a3066656a2919d08ceb8207efd55...     58  230138
# 4  4b268e0da036f44cbbb056ddfac6a28ea336d9cf299843...     59  101937
# 5  fd64ce519d3850ba9da4ee7fd0832222693193088e89dc...     59  152823
# 6  0c93f45dac9454a159daacfd6bb1f63fabd6c75d92a47e...     59  113224
# 7  f46b16150256c36df77817ccc9a8450e82532457dcb1ad...     56  131739
# 8  b62dc04dd4442d27e6a6c87ab82ad98b11f04737d54f97...     56   83744
# 9  6f230b30cb79f7b5791348b2a0464cbc92682d94bdd8e9...     56  163138
#
#                                                 chid  \
# 0  d6d145d0d058e3f63b9ec421cf9e1543b0c3e059d18c2c...
# 1  b599fb83473599fa2df4a04136a668c28df7914293f1da...
# 2  8de197129150d454df1639e9743c1aa11b1c1122a2010c...
# 3  f9cbad08a76f1dd9736a4fc51255eb55637ec0a417a406...
# 4  27d235e691a425098f291105f78f9877e05bb75e1f132b...
# 5  ee088992c8a0188647bd57018e2a0d32c5f572eab9ed5a...
# 6  02bd712ddaae04c874f1d1f1d74069da69b99da1eef7a4...
# 7  db35e8dbabf21f1ba960682dc66472ef9c5e3b2dcc26bf...
# 8  c42029ff9987b7bce96c132adbcbf38bb05b9d50207f3b...
# 9  30aeda17a7ad0a066e4a354460ee0ad0bf5098f6b1d76e...
#
#                                                 cano  contp  etymd  \
# 0  9c454e0cf3680075b0382394ca59b00ee9435fd829da29...      4    1.0
# 1  9f097cba6a70333c906904ebaad438356cf75b6abf5dd4...      5    8.0
# 2  439691cb167b272661c2eb9073124f5d422f446b0f92fb...      5    1.0
# 3  992679b728784192c17e90939918cbfae32ad1222fad26...      5    5.0
# 4  763fd2a91420f9b632c378ca82ff9e318851fa1964cbba...      5    5.0
# 5  f57fa89a86108807bb4c04dfc42a08d679ffeffe2fbee3...      5    5.0
# 6  2cd8983df4f8fac49c6bcb28432638d7bf538fd22ac920...      5    4.0
# 7  aa93e894a24e171f2eb9d2e48db31c0b6bc863a62d446a...      5    8.0
# 8  44265db723e26c1cfd830a1c8d9eb9fef540a806c75491...      5    5.0
# 9  2242b3ba5e82a24aff6fa4e54b871a4e677e53b0d1c4d2...      5    4.0
#
#                                                mchno  \
# 0  8be206f97d10b57a46ea0ef5527155a0f9b48d16255b70...
# 1  dd280b4f35a02701142ba7de47abb9736deca3eed86474...
# 2  9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6...
# 3  bd2b3523b4ecd652445b75ea7583c92f6f02af3971251b...
# 4  156987f72b8993b8c5a898fa76f3b8e6454e10e18aa238...
# 5  c2f959592b9f6b1ea8fbe12e9a4a1ac0fd0b2543dd3fe3...
# 6  466f3ec97458ba5e90f0fab6fd7433c1e3ae9150e8229d...
# 7  c76449edde6889cc61d4403b96b5fbe097b709fee4ee8a...
# 8  e8d98e44151198526e079fdcc7f44c1e16be6f1fc2fb96...
# 9  f6ed25e91e9858ae7ca6a24943175e6b9569a7ada6bd5e...
#
#                                                acqic    mcc    conam  ecfg  \
# 0  2a608b081c09492bd2bc96d7def5371c4bc9cabf324a98...  272.0  1353.00     0
# 1  46f63555d29f177290dfe20e989146fb033e453f1d5ff3...  320.0   305.00     1
# 2  9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6...  494.0    20.00     0
# 3  70dac5b1dfde828f556a93321a649df72891db35430588...  272.0  8371.00     1
# 4  89b1654aaef0b65b1868004cfdce2dcbb67f15b7fba535...  217.0   163.69     1
# 5  8f6b3ff512a001e0d1988c6cd888ef8c74112fb71117e5...  275.0    10.00     1
# 6  d0c4efb29970311d8492fbfb19616b631f38593cafff95...  282.0   125.00     0
# 7  bcf6370b700fb26d1fab05dad5de442b2bf37689cb55fd...  320.0    55.00     1
# 8  379166ff4a62dac343b4b734188aa618716cc496e48b65...  276.0   222.00     1
# 9  8f6b3ff512a001e0d1988c6cd888ef8c74112fb71117e5...  298.0  3090.00     0
#
#    insfg  iterm  bnsfg  flam1  stocn    scity  stscd  ovrlt  flbmk  hcefg  \
# 0      1    3.0      0   1349    0.0  15759.0   -1.0      0      0    6.0
# 1      0    0.0      0    306    0.0  13451.0   -1.0      0      0    6.0
# 2      0    0.0      0     20    0.0  15759.0   -1.0      0      0   -1.0
# 3      0    0.0      0   8339   42.0  12381.0   -1.0      0      0    6.0
# 4      0    0.0      0    163  126.0  14786.0   -1.0      0      0    6.0
# 5      0    0.0      0     10    0.0  16115.0   -1.0      0      0    6.0
# 6      0    0.0      0    125    0.0  15759.0   -1.0      0      0    0.0
# 7      0    0.0      0     55    0.0  15759.0   -1.0      0      0    6.0
# 8      0    0.0      0    222    0.0  15759.0   -1.0      0      0    6.0
# 9      0    0.0      0   3100    0.0  15759.0   -1.0      0      0    6.0
#
#    csmcu  csmam  flg_3dsmk  label
# 0   70.0   1349          0   -1.0
# 1   70.0    306          0   -1.0
# 2   -1.0      0          0   -1.0
# 3   70.0   8339          0   -1.0
# 4   68.0      5          0   -1.0
# 5   70.0     10          0   -1.0
# 6   70.0    125          0   -1.0
# 7   70.0     55          0   -1.0
# 8   70.0    222          0   -1.0
# 9   70.0   3100          0   -1.0

# %%
df['weekday'] = df.locdt % 7
df['h_loctm'] = df.loctm // 10000
df['m_loctm'] = (df.loctm % 10000) //100
df['s_loctm'] = df.loctm % 100
df['mins_loctm'] =  (df.h_loctm*3600  + df.m_loctm*60 + df.s_loctm) /60

first_chid_mapping = df.groupby('cano')['chid'].first()
#把chid換成沒有重複的chid
df['chid'] = df['cano'].map(first_chid_mapping)

# 可以檢查
# df[df.cano.isin(cano_chid_counts[cano_chid_counts>1].index)]
del first_chid_mapping

# %%
def str_trans_num(data, columns, reverse = False):
    mapping_dict = {}
    new_data = data[columns].copy()  # 創建一個新的 DataFrame，以免影響原始資料

    if not reverse :
        for x in columns:
            for i, str_val in enumerate(data[x].unique()):
                mapping_dict[str_val] = i
            new_data[x] = data[x].map(mapping_dict)
        return new_data
    else:
        reversed_mapping_list = []
        for x in columns:
            unique_values = data[x].unique()
            reversed_mapping_list.append({i: v for i, v in enumerate(unique_values)})

        return reversed_mapping_list

# %%
# # 如果還要轉回來就先跑這個
# reversed_mapping_list = str_trans_num(df,replaced_cols,reverse=True)

# # 如果最後再轉回來，就要跑這個
# def num_trans_str(data,replaced_cols,reversed_mapping_list):
#     new_data = data.copy() 
#     for i, x in enumerate(replaced_cols):
#         reversed_mapping = reversed_mapping_list[i]
#         new_data[x] = data[x].map(reversed_mapping)
#     return new_data

# 最後跑這個
# data[replaced_cols] = num_trans_str(data,replaced_cols,reversed_mapping_list)
# Out:
# [{0: 'd6d145d0d058e3f63b9ec421cf9e1543b0c3e059d18c2c37739c7f3453168a07',
#   1: 'b599fb83473599fa2df4a04136a668c28df7914293f1da0a4cee5e3eba7ff320',
#   2: '8de197129150d454df1639e9743c1aa11b1c1122a2010c0e7f0eabe4299eb31a',
#   3: 'f9cbad08a76f1dd9736a4fc51255eb55637ec0a417a4069bcecb43870967eba5',
#   4: '27d235e691a425098f291105f78f9877e05bb75e1f132b4039a5373ad46882af',
#   5: 'ee088992c8a0188647bd57018e2a0d32c5f572eab9ed5a7998ab8f821793e9c5',
#   6: '02bd712ddaae04c874f1d1f1d74069da69b99da1eef7a43e75662ff01b3c1d88',
#   7: 'db35e8dbabf21f1ba960682dc66472ef9c5e3b2dcc26bff168d6131d61cf2c7e',
#   8: 'c42029ff9987b7bce96c132adbcbf38bb05b9d50207f3b07b7305684ede84611',
#   9: '30aeda17a7ad0a066e4a354460ee0ad0bf5098f6b1d76ecd2e6ee88062402b81',
#   10: '9538dfec8ae2639a659e60a664f514edea2352bf9a38fd628b059d8c9d5e913e',
#   11: 'ce2cd190129e532608658854e97d8ca28d6c716b72fde66095cbe5c225d9778e',
#   12: '16216f6229a384300c3cf863508380a69f381fa688310e7421fde6bae103d1ac',
#   13: '75a8dc4023c74b45e74461a41b2c49c4062e1c90f34259c0fcf837ea890a90a8',
#   14: '4689e5a7cb535062268076032f211cad939db41bf8eaf0b0903a0c5ada0d5395',
#   15: 'f6eef08a029c350281eac9dcdef0f2656e0e1effbe24e048f0cec9664d9c6e69',
#   16: '3041c8b2f8c067cb9af716ee470fcbe5d2d7ec8132fb7c14be833efbe7acf528',
#   17: 'aff7fb668f72a7256e5c881625675aef9a3a517bc77f25bb184b79e0a3deb172',
#   18: '0ace3ca6010a5ac4c858ad6cd7ab59415068b0cc8a27a61acfd183f636eeed2c',
#   19: '88d7dc07824f0cb1eeebc61a66a89da83ad38faa199410a2afead7a186f94e79',
#   20: 'ee5cf79a2a60ea6f69520566182f14b18005655ac1e5f09c788782b71038c964',
#   21: '74c73dc946ad30f7ac3b3c981288e0f6f21be44eb5d8e0e02d0aa0213e818de6',
#   22: '08d2f009d8dfe3832b70354e3221a29b08fbaaff1644ba9b95a07034cf422c65',
#   23: '86b863e6fc06e2df4d1fa72fa889a214027a0633b1c6bdec8f4a5d88dcc0fa42',
#   24: 'cd73bbf3b9a3b429ac9de9bc7c7be5b84e10a125af6fc5e825560968cbbdb513',
#   25: '567478d45a7bff0c358bb5deeccb88b571fe4bc4ac9c8b9020dc1e87a4345b0b',
#   26: 'e0a420ffb677442b8fa0679f3c52901a99090be8aff75bf7c8d42cce1f50af5c',
#   27: '4bc9965a7b78db7ecb00870b02834efe9358eb7d26c884c78e6ba4d97ed74faf',
#   28: '6d09fc29d0d1ea60836e738ff072fede29cd7a97e0b62dbfa6081e2c1bb71cc3',
#   29: '3e51cee4630761e98d03f91c1397a06f8f5a2f37c13825da672c3df156171df8',
#   30: '386603d67f9102f4d6c9a0cdbdb6c0210f47424569c709862c3b640d6c1d55b8',
#   31: '1c708a7d1e75e5eb508ba4a8bcb86c8c78524ae2a4160674d8d02a2d0903c395',
#   32: '91efceeea67075741eb30b418a5d5e526ae80d4164cf383535288bdd105af723',
#   33: '46daaa21cdd6caf4d7049347a70d702ec60d94551d185778bbeeeb856c7326e7',
#   34: 'd66d9fadb19959fac8b5a2423dc4192911e0dec323bb4d8dcd263703ab06f65c',
#   35: '5ff0f7deb4c5e80f1b803d3503a3bd72ad5c561a7db3a713425a60b24f52c541',
#   36: '2b616fe0119d0649447081293aa925e04f31e922059ff29eeb5016966eb76fb3',
#   37: 'aef455b415370308837cd805b35d9f352ed26d6d77869f1ce9e5bf555704bef0',
#   38: '36a2c7f1f4f71f7815a84ccbd46cd2c17c70e61320c1481ac8a62096780c608b',
#   39: '1a0293754adf0ecd18d5077a209db714ec258a2c8655c5ac5143000f42e8a7a1',
#   40: '32c346e1bf70974bba3b24c968ed756bea55161dc0ef02cc9842cb0e42b78b47',
#   41: '8458d6c69921084cdd279bf362cef8e91c5fd7d1ce9ad7384fe6f7de3dd9e057',
#   42: '4ecfaab18fcfc6d857095c63fbe07b88a7855c04cca2644d437f6c0d9bd8b897',
#   43: 'd457f607e68b658a84cea7f91ba05e388671e038e52667c5d9e5c5629fdbc57b',
#   44: '95f1860c704c14e980882247e29a6c8a519ecbf24857ba8b4d185c16a3b366dc',
#   45: 'b83480765237ef36b731dc5feb77aa5ea0ec5ccabab425066ddbb93f0d708eeb',
#   46: '7800671fddf6a05dc0678c3bd1d7b6fdbbd8884861ebf71111a4e001b1ce1da5',
#   47: '413d08b4373a0eced6a30dbb9da1a8c72ad82c194b3123b4025ef326430e9e04',
#   48: 'c6570d2bc1b5e9dd8aa7eef1c5cb1efe30cd87e870ffb10d4b9cf9378ccbef30',
#   49: '3c98a75a21c56f81080ec4d78e37e304e05731bb4d4fd66fac33f26a9fdb6847',
#   50: 'aced9641bdb538e0aaa855c66f7a0f05755182f33fe5ed6a6e154b0f0c84c34c',
#   51: '8951b3c00fd12f507886b1921e34b64a33f168e385c2f551caeb302dbf608aed',
#   52: 'f2e8ddde2e8bf8955715cb9d8b7ee0739f3348629b1703d15f5cafef1acb42d7',
#   53: 'c9d143dd2814ea27a458963244120cf2e583be5f3c966c72db0e2aab2a714ef1',
#   54: 'bce68dc609f6794a7ae83b33a28f37a53ec57082739eb917316576cd0990f91a',
#   55: '442ea355ac4102cbdae592ce22640506d11bfecbf55c46bc6f89eb20d785e0c3',
#   56: 'fd03255de2a6e949a6bb79d62caa816bae85f3966b63f1c26ec2e1fd308a4f78',
#   57: '8d7b5e5535d9457129416d9c9f1eef6736f762360cde1017a1e10034af35b021',
#   58: 'f5e93ca929895e6994c82cf14df9179163e8e101cc09b66e269f565da2c8a60f',
#   59: 'c62202c88f5dab8d06d276aa869540a810c95dd0b64484bc388cc7126e97e622',
#   60: '2022a8003655f662142cbe990a276a1721892aed6a7971d2251c3afb82e41564',
#   61: '074574ea80e053bf5b16528423ec2b5bede2c2c2c475fe6acb964599faa549c1',
#   62: 'c5b19a5886468ab439395bdc9e48ebc49d1befc9676aaf15c01cb3cb49829f6f',
#   63: '47646e4507c28fec42bd48ebd07d8018b653ee8ab71c5ef5a33cb884528b22a7',
#   64: '861acdc486e7fd0869223af2707b47d103050847ffc91537c5da9a030e199f18',
#   65: '89af2f19ae8c8f70499de8cdf3221c442106b0fd68808c182604d030099d67b1',
#   66: 'ab2f14c9e4e9f180b16b8606a31cefd6ea8bb75e388d8a555576eaffe6153aad',
#   67: '09313f4ea71b20665e1dc4c5c097b7660eb9772ed5bc4a2764e2ac3ac1e3122e',
#   68: 'f9f5a1241894dc64335d4198e2e3ca6922fcdcf3472c06b38bda56257d7425b6',
#   69: '188e5f4ebba8573b8fad4a27cfaed027bbc401f0871bb92712e5286d01579d6a',
#   70: 'b85d596ad3c4007492be4644c21875b38f93d0fdd0e62f3dcf9076f836686dc8',
#   71: 'cdf1fa131799c7460e11ecd0a5641c0493bcb736392c001fdafbea12cbb21a7f',
#   72: '7d0e1e1df7dbb7cb28790833c518e26cef044d6ccd215c2967970d923dd4e618',
#   73: '780154164e548ab7e1cf4446845585006a951b3cf48e84b49ad697cde314b499',
#   74: '110b0b8d8878560461d2e21a0733a1946a1a173d557db592cbe14f39ebac4e9e',
#   75: '10be26026d398a2a82e18edf0059dacb391fb2ce1f3535c9056a89369c7750fa',
#   76: '5b4cee6887b72fe8fd51aadc80cf5741ce8ccba5f4c54a970a5cdbd0f2aeae1e',
#   77: '61e23f624e6f0cae54fc172c781a118051ed4b460f37db5f82e35f6d6b0ff818',
#   78: '4b9d80bd0c9297a5c37af8959a580e28ae595d5276c500b76e8d68e72f37d6c6',
#   79: '6c0b665a92e53d35cfd7acb640450e949f77bebc48618e0aa61dd66bd069c873',
#   80: '91f8c4f8d8bef8c094e7fe4e0b5f018cc14719f0c9e8814ce26454610dfd6d05',
#   81: '4940119a87cb440be32888fabfc0cd18687f5c099d7146d5d27a5ad61b46df95',
#   82: '49d538ae2f8ab959b97c27e93a789eda6654c4e3f4c13e9dd4315980d3c975b1',
#   83: 'bd9ec599bbda000c362059015f4e3357847be94cd9c06a44396f76feb495f22d',
#   84: '67b629d6eec02a39f5ca8bae710e2f3859815661265234084ae430d62d52489f',
#   85: '7ecf1e91d220dd2f969ab7125b9d2841f61769e819f5fcbcb30b28ec009b0996',
#   86: 'c9745f9701fc8f082baf0cacd62af8140fb590c3f7efbc6847ac1d3e5a531a3f',
#   87: '5839ed89f647f6bc8a4dcc4ebc2c2362fb120ae12b79603f601795c55452d71c',
#   88: '83f1dca0963f0d4ced9bb32cb17e74a4364132f11c292baeae2b84f28af9b298',
#   89: 'b953e4c04691bcfdf0f4c576899998948ae82ee422ca323c98c949f08b1e6ce1',
#   90: '10b9b94c01a1e5c9beb657e21f4f202d9ed5a99884b1893a176f6f0853ed630a',
#   91: '03dffbce8f1e647302f4c2ba36951b87cb9663139693a84090331c9c1eb4e9c6',
#   92: 'eeff81e5d79ef28e3f4f34e82aa94655a42d491a1b958b68002e9319ccc3c04e',
#   93: 'f253e0770fef3e14f578c811eccf92bd30c2b7c423b10baf8fe43fd1ce1a1065',
#   94: '7dc3708841bc876900a822d46ab2081fb27824cf0e386a6d7d73f9ad2752802a',
#   95: '893a0917de8b010cf01083b83561695f68084d28f01b51f70e400befd2ca5a79',
#   96: 'e082912d495b9aead6784f1962249681257b4d0db8ff2c9b2a5ab4e2fae2d5b9',
#   97: '6cc26fc5d8bca8ea7d0edb6d5e8af943d10fda2a30a7285107c899e7c3ef9bb6',
#   98: '8c589dd139f01b7d65ec487037c84fbe71af3b0bf677f9662082335df76a7238',
#   99: 'd2bf0b2d96d360bfe44091c3e2ce0de2d29e9afbf10d517f0bab5615da9e3f49',
#   100: 'cc0040b6219ec95e694a131c4e9eb8f3d1f414b082293bcf9205a1dc9b3b7e1f',
#   101: '20a2132bcb7d9f2d6b7275c55469ce069c0396614dcb02126c4c81dbddf622ef',
#   102: '447fc7a36e015fc23a2f9fc52c10a7ee483bea29a71d218ae97d7b26ac6fb09d',
#   103: 'baaa410036f5f1c2ec40c617f6a8d58354af21f4a7e0095236f38e1de78b76d6',
#   104: '9b9f586d46b3e4e274190fc7566ad3b170a9c28a7363493ba6bfff62ebc4379f',
#   105: '18e65c1f7e1a3fefc084650ac6c04f7f79c59b95fe3dda0df162b6bc7e816380',
#   106: '70c1cfbcec35f975e306a7dc8ab52eaa984fddc80107a7bd3502e32e53b1810d',
#   107: '1766c35a461d9aa129ea4ded0e5ddb2a0e37db90122e30247d322c31be6752d9',
#   108: 'fef3ba8e87dc98991f6e80737a7aee4b0a2c2f7d0c463feb7f4ff9d4bd378258',
#   109: 'f9343578c6ca539930c96bd2738e59571dcd48073fdb5d2c04bf626c95f0083b',
#   110: 'b898781ac6e00bdc4ed6bb3190d27dfae7062628072fbaa529f2820faeacc86a',
#   111: 'd823789d6b063a497f9598bda976505809f6df1356a6362912edfb1044671a9e',
#   112: 'd3dfac4dc1684e4ae0bc623fee1bb8cf0bd4d0e21307c0ec9ead78ebdfdac5cf',
#   113: 'ac38d791483de7fa08770405cd4db76c21b51ebee54cbcd37bf7e896d6c2a0db',
#   114: 'a313eb0656afaef7c9bcce6bb4a6fe8f9d5a776c328493f0a55ac6a370596901',
#   115: '9238252aefc657c674a715d295be8078046b4a2cbd880c999ff201bccacdf210',
#   116: '7515060180bab5cdf69f45d749737f72fef02b8ed5c0a917702c1e3340382aaf',
#   117: '77ab3629bf85214cc3830e79a953faa8a8a715b025dfbaeac3247b2d27fcbf69',
#   118: '0a5a800cfaadc40c2aac25f7190f97221c187fe0a55f3b38de882b85a137e9a1',
#   119: '87a0dc4aa3c24370c559fc683349a0fd6c9ba2d0745dd0665151ee3f72250a86',
#   120: 'b6a17b065723b3a072afefbb20c165aa18815db47826b4b74ab619656e832e65',
#   121: '703320d8f3812836cfdf8673d575301ca306c70be8fbde1cdaec1a40f91f8427',
#   122: '6743238f3ddf83f07f72755af2b559bc4f5ceff78884da4d7a79a7cdaabb9b56',
#   123: '1149145060bf4b73b1b91eeff34d15e418aef6363a657dc6311c9e67daa21218',
#   124: 'e69eac97a5df4f792c509f6720fa9c1142f80faa17e3a1615473a3d2c60c538c',
#   125: 'c362c1a10941fa20fff9e63e6d8d9103414e4cf258f4d545d7840c0f39f6ffec',
#   126: 'd636bb2cb697dc3b8751fe1017830c8b72d57a7f43337d9d396efc06f088d4c0',
#   127: 'f93e5b0a06b612a4a0eb3a8c0cf3d810019113dd732668659be1648f65d7dcba',
#   128: '5e5b8e3b056daa7acffaee0936afb5953ab62ccb7a29a9b174045b0110907ee7',
#   129: '905e0b7204f3054d37121dcbd8b0dbeb69438d48a4605ffaf47a06a61701f83f',
#   130: '3a5a0249590da9e3e4c4c9394b351c27936a03236e9849043b11e15f58a59fb9',
#   131: 'e902358f713f0f0d2b358f6783dd6cc497e2c1b23245f9056e6dab1003b3448e',
#   132: 'd66974ab2efe3b9ae59883b57e765d7ab474182371dec680c2a183f2083491bd',
#   133: '40f16354ab1aa98f38e0c90a05ed3a07dd698a2352375b9165adf0e263ee4adf',
#   134: '93eeb7f633f192c693d18287a8ce5c8fe495600bdf0c4cee2f512b956af3e1bc',
#   135: 'f33681c31c992789b00f148effae9109da45cc3cc7ccf5cb41002d5218bbd901',
#   136: '3fa81c9b511cc559ecfd12fa2a5e074666d66a940b15053e21b264dda6d8c464',
#   137: '93ba34f07fc5d7b630c4d8aa2b537a1f38fb827bde7ddd12e59be1b8198dec18',
#   138: '22a23d1fbac53bd932dc9ea61b589cd6fbfe6fd56f779e9f36c50a57bfa30bc9',
#   139: 'c8f7fba40cd9706d2553476f0f2f8968185fedf53d6596ceb734db7bcd7d8d7e',
#   140: '2346f26a626a4dbac765d2c3fa741e29fe4956fa4e7cfcd17ee3b63c523aeed5',
#   141: '2efa6c63bdad4cfb9da6a6a03239c83ed9e0220f889793289e1cd81cb2bec1fb',
#   142: '770f5465ae28f81d8e6c0b8647cffb4af903d47e1c1f85182bca2490d147aaa7',
#   143: '0a23ca39244accf1afd96cb8e83da52501dba2ced4476869e65b04ad30f2ce98',
#   144: 'fdabbe359f0ee41b8eef7ba0d8712e3bcac091e2171206c99a06833d526fe01f',
#   145: 'cd8ce396e5d4be692fd30054ea551009e2addbb589b2cb6393df88e9ab66792e',
#   146: '0cf42e688abe91a744ab23326caafd72d1a1009441bf48f7d497decbf144bcd9',
#   147: 'b473804ea576ddb7eecf9cccd3f97a87eb6d22b11f9b9a634d434680dbb5ded9',
#   148: '942ed32436425bed632b67131b3fcf30cf9abb7faf906050e18dcf0d2eaed7b4',
#   149: 'fa278c2867727f67cc2adbd8bb22fde2edcbc4dcde004059b025a4da87ab4310',
#   150: '6a4b686ec74d8fdcc453d1cde997a9ed8fe48b33caa08b5ea77e36ad41aeebc9',
#   151: '629ce2aaa6add6e0f64bc9f9053f68fc347b50edd911b9bb49faceddcde0d613',
#   152: 'b722070d62f7147120824a5594ed56d886a96919d0b7a1c5fc00a2b69a664b3e',
#   153: 'f6123f1fea30670c4e285a06e7ecb21349a629a60ce22f12201423825358e49d',
#   154: '0fd57c6b73dda5efaf84fb961199ec6b3ddf8c5817fde551dd364b4e1dbc5351',
#   155: 'edaa585512d0aa3aa85bd8ed25e1f0a21f14c3f9f7582080c558e416ee51d9a9',
#   156: '7aa5a465ad41801ae61cba0490f4e3a9dac89be62ebf84a4874e00ad27d71d24',
#   157: '80c91f333d46b82755872c5b1cdb3767203a5394cdd4e0215dc0b4b174021626',
#   158: '1a17e197f361d2304454bebd179ac6580add60b977e77775237a9d7660cd2781',
#   159: '556b64b40c4f6abc24961e3b2872a3d5c7c0c56234f88fb434bd99a8e71997ba',
#   160: '656fc4a6298207505a719111731bceb6a5e4f6346b765592208c0e8342de7448',
#   161: '3528ae1fbb1e1cf18c056117ebd17871d4926fc6670472e39f6054c2df54078c',
#   162: 'a00b387ebdda430648906e0800761aa2afc2667af8482e01e0b9ca1efe476e5b',
#   163: 'bda8f68ce0ab3c60e91a9b7c32b7261bf1c5cbe2a07fa49a8b36ede0edd73221',
#   164: '98abac6aa364138ab31590c0392509123f3cbcccfaa091721e00db8d6c082f11',
#   165: 'd2da7aebcb32de74d22c0331ae2de4e3e9e3027c4426961fe10fc73960ee9c48',
#   166: '95e535f47922203530e4ce4dafeec5f6e81414ff9daf0e49e7a4fb91c1c6bdd6',
#   167: '71fe305d3dc820c2884b3d5d7e83b1bd4f06f9dacdbf9556224c48bc189e7ab5',
#   168: '3e357f15cfee92610d18cd989a08e72c2f88172124eba200dd927d07ec426faf',
#   169: 'b3f280c27f1e9ccbbc84b98c950f995c951ba3b3060f75b474437e26b8197477',
#   170: '0576b660af484cc5baa5a022d2a2c414e387641f8146ed9dd29ed6a05346b2fe',
#   171: '51f16bfb8e7e3bd8ec92e7ece45100c301908e77ac4df65514a34b9bf41111f1',
#   172: 'd3fe04418e1d27602068ca3a9c652d14137a525d0a9d2ccc2534ccd0ff2b2c16',
#   173: '2bdc59eb081daff26581f7ca9285b9044c3c69a8e0722664863bd73a666ce85b',
#   174: '8cbe499a6452ea89a3f291e61e4c1efa33c8b99f1d6f98f79d264da9afa1c595',
#   175: '4c1d2bef90825cbc1000ac1dfe85a3568a3f9e89eec1c3d96402056a0a16c4c0',
#   176: '750d0db04de133158b6b4ae6cecf64388f1237e2a99a5c08805ee1518411d96c',
#   177: 'edcb3fb933139a2ca2b22f1b49cad9285ecb489b6b0d8f14ac10828f214eb9d0',
#   178: '130f03f09f746b919a9b383efd048f79e1e46a73ec8fd67b827b134997aa5ba2',
#   179: '0698c435c6a008bd1cc3053c46208aec9e793acfc15cd4d2d93e6fb033ec02ec',
#   180: '648f106204e1b5398f865d52aecd274a708af2dad7b63435d9a1a16eb42afc6c',
#   181: '0f334725545279905b3119b8d882aafe8f6b8a01ec65a43bad1516be7f16f108',
#   182: 'f8a7d85e1e9e7bb6ace69e8a62a4cfd85a47cfa63ef783f126c0d12b1e900e0c',
#   183: 'fb8e3426e1e46d1a2d8dfd265a766053b8339ee88279fb50234f7fc1be20ba77',
#   184: '017f76fb87749bbc9bdcde73ceda0a02251dd3cc48ee10c54ae3377feda8dd41',
#   185: '94ac5cd01c13829ffcd6108845a3eb3dbd88b536e7cb626df52f117f86ed6f89',
#   186: '1d0e8ceda293b583b95fd342e081d38886d8064cd44a164490e260fb073d9808',
#   187: '380f99e93e749321d9c08147da28ce8543cdb9b955e8d5c00a7bfb2ea2a73ac5',
#   188: 'b5eecf65691b15bf698bbafe2af2ac9679ac77b508009c0f8d8b640f47f5099f',
#   189: 'c9657131c72d89f4487ffc103c5e86755b56ab2327a311ec60b6e61ce039929e',
#   190: '93adac6d6eb380d2e15f5d7888c2350763e2081bd15d067e3761f589a5aa8b7d',
#   191: 'e66998371b5c42bf868ebe898dd927a6630651300d443598fd56d27285f8c660',
#   192: '7624a3e609deb4077bc343704f31fb70a2bcffe9169e1c5945be0b93f6543044',
#   193: '4c45cd0cf2b35bafd418deb78a03b141194de4dd0e83d05dcf1b7fae6ddeba38',
#   194: '35e4b2964c164edbd2791fa71516b135146a038e3618bc0eeb48e5ee22f8173b',
#   195: '00cf9175ce0263659e10d6d141803155f0c10db83c02039c5a78de4ddf5d4528',
#   196: '84811fcac568f71e8a86729b0819ccca2122c299f965155344494d97a80bd49f',
#   197: '5dc1e79d5c475b60e2f825ab90fed0c07a33b37baca9ea1ce89992aacee68f08',
#   198: '7f4f5ea0f0c5640277b42bec13ad249a60689910487e0c699ab2a9836b0d07e4',
#   199: '1330c2fc0bddbe4ed36e473603ce1bb2dfe4dda4f3ef3495d88e6ad92f87a7dc',
#   200: '08381023fd4b102e698f8365a14438749a931c448f62e9f9528e3192bb49959e',
#   201: 'bf4bf4c7db62f6daf4887bcffa8f12ca24a800a4f36f87756729056b20650d4b',
#   202: 'a5d81c77ea78a258d628f148e4630246d34113f1c6ad91a8f8ed6844663b99a7',
#   203: '93365a8b77d48adf8f7ebb97550e0b1bdd8bf52bfce0f779f2c556a4594fc0dc',
#   204: 'd602147c2d49081602d66c0c148cbf33cb2698edd1743312ed032e7f2c0264e3',
#   205: '379ab79a7b9ebb40a0fad6afead2e6acf63b69bf3df5e0797b7d54ccb0f297b3',
#   206: '512665e68df4ab86cd99fa58db6148b282ccf51e3be8696d11e7e5fdd79e10a0',
#   207: '143e415dadc9e6cccc47b87e3fc522f59bd11448addb81e8d92455cfed0f839f',
#   208: '7eea1345fd8d2bcffd8157a38ed2964557d69959ab4eb2b052836b09876efcea',
#   209: '3f06ae77c078064c809378e220871c15b7a6473cf609288a06def915551beba1',
#   210: 'd8e7bcd8ef047688a92ed24154a625a9227811e36eb260a171197a485823f1e1',
#   211: '2b2423e2fd8b6546a409762b0e7e00800ca69a2adf41c57b973728d4c0fe2e6e',
#   212: 'ee374805014fe3e39806611e3a4d817cfe7e974677ae7d1e063e2a4aa11c849d',
#   213: '14235fe4db2eeb4cb1f3b0892b6450a40d778c9e9a0692d0906d001585e0db8f',
#   214: '756592c2d4dcd789e6c8ed4363539e9e11be2feb43738a0caa2fa65ccd5b25ba',
#   215: '7700f4a7022043561b29031265a5dc0773e5b958eca4cd7aa5372264d7c6eabc',
#   216: 'b298dc8c890bee7e65ed2c3504eb0df4cfb0a91ebc881711c759dd681b7912fc',
#   217: '5464d663a979b9afa1b365bcb4b706b62d58d9ecb7fb7b224638d08c21005701',
#   218: '59a63b94307d1b49f0dd53bf0130923c6688179cfd2a6021c360253080f92610',
#   219: 'aa3b7328023d716597ef60f93b6b19d9e87e1d3f7ebb86bf37b94fa0adbdc952',
#   220: '876b3a44fda683df264f45ada20dd9e137efd014e59ae6052993fc535cee7200',
#   221: '5657f30bb5247e740acfa75fc576cc284a67557598635d4994fca9b4a1573772',
#   222: '1f17484bd5d37b282ab53cc7df47abd1b8db50da011f36386eae07615c10bcb7',
#   223: '5576a3ccd1f20e69e646ea45102c7e8a392ee69359e149b0cbbfca0b8108e65b',
#   224: 'e8f2346375e2915036d4c06e6b65a61be90a1653f2cc0a5bf090a0d7e4b805d9',
#   225: '9ca5b3b01daadf824cd90d8d185879f8f33023ecdc6cfbe8571dd962d8a6a7f9',
#   226: '5b5c0a9698b613fa9dd01086b84bdb7db9a4ac733e46d90a973fb32703dcc1d8',
#   227: '114101bd1f8b4ede0980b9420e5a4f1f4be0fd5fcd75b96e449e14db6e7ba1a7',
#   228: '34e7573217d3cc55cf3b42439d1f1f6671359285979f9c3ae1de0649e2ae2e1c',
#   229: '63bd6afa339b6d30de4efbbc5ecb18b9fb6ff750dc5b4a25391f2bdd54794f2e',
#   230: 'd626c601acf67b97af1938560e6b7224119c9d7e428bb557c0dc03059021bc12',
#   231: 'df4771c56977a7461e9f10d9b40e483fefd42ff46a7259482fb6ad5f73ab8b00',
#   232: '446378e8c65fffed0a09e6db6f20ea388758195c09ec90fcf5a68a62900612b3',
#   233: '95bf6b442459569abe9eb36e7aa0603090fa0af4cacae07ce63183160a30aaa5',
#   234: '822a6f6a4b6454c6a415f44e24a593ea317938dc93ab22ad21fa7d062b47dcde',
#   235: '9dec6be2f5eb0ce92f753071dcf83ebffc0a739849f5492739aaca4c8e6b1bae',
#   236: 'c2902882e513cc103316613a1f06574dd4598fe803874b13b6a4b1539d02c5bd',
#   237: '11f1da13b8a808df44ee929f50743db2804bed0169a8c827655c4107f195ee6d',
#   238: 'a6e9dae05d99cb179f0b7f8957baaea359654c74fcdd722e521b5d285df96f04',
#   239: 'c096bc6f501a77067c345eeb030dca34a1d32b579fbdcd05ef17b02471ec7ba3',
#   240: '8ad22d04a533c8dd454223604c94d6c215cf724edb448696330b5befc200da65',
#   241: '831043d0b2bdab24cdd9ffb0b4baa9ee93d305eecdf93515c3b87ab135d244fe',
#   242: 'f448ccca85ad86dc76576bde02abfa244a13e894be7c0fd19240bcfb632d60dd',
#   243: '2680a3cafd0db8ba5a0274adeeb346dc73c69d0729de4617fa45a102631728ad',
#   244: '09802ab6337f050c51e8e40cc553b3ca7745e747d4f0217ca2a5f44bd5b9448e',
#   245: '3c52740abb04850f6c5fd338fd80c4651f9e78cb82f900a611b76c21a3227472',
#   246: '007ca9af91929cbfb73c2f1fab2f4c2c1758cf13fe9d8a7ff2d854ba45e82951',
#   247: '5bda5397b77d088684f51208afc152a14b6b701687cc9a9b9e053dc4615d9f5a',
#   248: '4f1d05f6c8b41a291da4a37b9ff41bc1cfc0e35fa1de543f7f8b90c903484b76',
#   249: '44d7c0aeaaaefd47cb30cd33ff7b41d84942f710d2c57352eec3cd38b383ba85',
#   250: '106c26f6391df871824ef6f112c883320b7a806b99c52870c698d6c7e90f3a61',
#   251: 'f4483107328bf9192f730c49d3451c4d4e2abcaac7774e3e66df5503d4fe1181',
#   252: 'd597de6d5cb4f2cf2775372ed353ae1c360c4eb73c2c3b54fa22201b4f3369f7',
#   253: '3332c5c9360c72968d5645b2b3e5c572a4708ae2458e1c89b46ad23ea5cfe5ca',
#   254: '3b3423cb7dc23597d687660a27e0e7e2bcf545410f75c4b9aa1280390a81de5c',
#   255: '306c220e740e24d83bed3e1deaf59bccd03ff11c9b6464e100370d9aaf71426f',
#   256: '28683ec87e647bcfc84f5d13bce0f785e826c38c6761c7e9621904ec7445e941',
#   257: 'a56392e931af541466230a8df882f0c8d6791599e77cf5cc0fd603c4a082c7e7',
#   258: '5c7085abcb9a41798c48f27633ee9d1c436c8286fd20ae001f4de5cc887f3f40',
#   259: '9b1b12bac688dda642ad9dd0bdd12f99c8c60e6a466a592039518bc641abcb8a',
#   260: 'be132711d31b90516ed1b79df41a258b7ca15f066fa1f0877503050e64df0915',
#   261: '8bd65d3c25ed1003750bb287f3543a6ef95f3b4ee05126952a7ea0b833a9da1f',
#   262: '009297a53bbe8526af788898dda287b523e9c1a002c38ce79dc34542debe8387',
#   263: '268ab8554f9da4c64614e10b06deaa9a2ba3c0deb1b62202254675ac8b1f4eb8',
#   264: '64a90f64db03c621330722b40ca35302b690de8d9f86e24bda278052d70b8284',
#   265: 'e3953cb04a04c6406e9ff5622de2937a53a54fe614ad08dd595326bab5dabd9f',
#   266: 'd8689994659f118b1ad61570304aa8213840eb5500eafb76ba11897dfc9818fc',
#   267: 'fa81a3c11bbe41347dd62183cc3a0731e529da7000f46afcc6779d923f7874b0',
#   268: '5c50cb286b4d12b4436ee96ecce25153c71db843f9d8a5042c30a9389d099623',
#   269: 'bcd65e09718afe03e8bf39b909cc3d9721bb91fc1b82fb03581dbfef5a91ea08',
#   270: '7c0bd9153f5e1e4e62d9715eb3fe0057c123a999a4b14d80ef2bf82d0bb478a2',
#   271: 'cef356426f5f23e5989831fc10ec08b350ae034dc78bb9d19f5cf3c447ecf41d',
#   272: 'ba04eaed3559d6a2c0fde58bb22f709c9ed4bedd907ce81d42267a3aff058b39',
#   273: 'be0cdeda4f5e1f490742ebc3e835d8c9e43765c8632802b60f7030c57c1b56a1',
#   274: 'd18075188a6855e591350d89175c37eebabdf78696ab8c4db8452ab1d9371264',
#   275: '38ea61f6274ae9fb406fb551ecf60e746e8102416c9071ab7d67bb808e6e648a',
#   276: '5aa6321fc09f0671d3fc8b4fe27d7d5e9a99d8de515ae0291672455d4103152b',
#   277: 'c24ca33789d5eaf9394a0e18aac46257c30169408b8388a8dd74cf06b01b8d7f',
#   278: '3626b05d2bfeb3de803d709b1ac1640a6818c5e79703be363e5eced9d8f836af',
#   279: 'ee5eb9097486adadd6522d0455626eb6216eb849f3955083a3b1ce51e478e563',
#   280: 'df3d62d1c509def1a7e3ee066d10de44a2d009a6efb2a40be16fb7c7d418fb7f',
#   281: '5f79a538974259e49b4ab142929f2a2e2aff7041866943837f592e69cd29d05b',
#   282: '865a5f3a84c1a4796f83175bd0023d417fc2a9e1705382c2d2bd42dd54279e8c',
#   283: 'b0b91d6071e27fcd3bc494c99dcc4c9f007df658af3d66e5d74fb8c9da7b0367',
#   284: '9f8bd8b032875dd99d688b20c4efb81fd73187b214fa7328851ca3b300db9a8d',
#   285: 'be0febc97b364b35726f2b571130459e5bbd7be2d3c984741659caa18b4650b7',
#   286: 'db699ae535dae14809abcd724cf77e8066e787e06b448a000be7cb411c553d38',
#   287: '85683a564d609968baf5e4bc14560d0aaa208b05522481eda6d9f9d019464c4f',
#   288: '5c434faa08bb12f8866db10302d7f3b607d2faac89e7dc723acdd3529d53a245',
#   289: '840ead41e45aba862ee79ed7d2b28d0d8012636728adbddf7ae3ad4ac2c20b89',
#   290: '144fbdf7b9c7e9a51e400c31ea5706ea201a8746ca9fcf28c4eed7ad9bbfa466',
#   291: '9c90a26d1713754fefafe93f22a4a241020a50fa3628bba75db7394c67ad2755',
#   292: 'c8ccc053e62f8b2cf5fe17a771897a180ff44e86ed16293688736aa8301f674f',
#   293: '4786c827d451f2fd3df4f1279ba6aa3957784a5f6c3e46f159e745d9e18f8525',
#   294: '3ef544feef6221a60489c9e7f8d467ad3d5aa0098f7e59ddedc2aaa7658fb90b',
#   295: '2d0d0e0e70e22c540475f8f082162570a0a84afae8776f505192af0e5b1c3a79',
#   296: '9593e608ac6b9518608bc3b269fd13db580cde75037ad96eac9feb85dfd7830d',
#   297: '6b113e1d8830a342f25b547fe7267070935357e5d57a5cb8a3cc43b765a18c94',
#   298: '36836abd7d5b582d52f83f13a2abef0475f4242b9da267915a7d3dc914124f14',
#   299: 'f7263a160903892a4c9b1ef78cd827a92d9f5050fbd9efd8bf9c1ede39e908b0',
#   300: '5ceca149a07336240f86ce8fb9ee1ca28537e59a50df040bc44480c65bc54239',
#   301: '436b446eca6fd3521a29851d09814a06ad1e4e094f0a46673454fac5bd685b15',
#   302: 'd9caa24970bf2f912daf265cff568a1de054d2be92739150a4b12432c0b1138c',
#   303: 'b50c40e2086512cb99356c43611011fa9aaae460840a0d871215a6f6b76cbb74',
#   304: '6fbc4f4464d3e59078926e7207ef16621fe6c3058a96912d58d480aa0c21787e',
#   305: '8c7a5d93a5bbb893c7fa4c27b98a02c40cbc18d58337a7108f036e1e29ac4393',
#   306: '4d220deb7f19fcab6ee7bded804cff950734dc76c971065741561d3a00d66466',
#   307: '24fcd3f90a9214fa84bf9aa2b37da04d8950cfc475a11e2ad09e34ac0899d92f',
#   308: '5f90902f9fdc6af5484a95a818de5c1460cc1996388d48cb8348fb4e47d1c5f9',
#   309: '9a31c9f3326dd82ea31eb86c8928fa72fee83e860f5cd49388abcf15b5792c37',
#   310: 'df32c1cb09d8d22430e734446da9542d191993cfcdea2d4a6de4b44d4503cdb5',
#   311: '29c10c0a36cc462bb190a63956c70c78d15f0eef43be08a83ed290e872cc11c0',
#   312: '9d2546fb839fa22a932d3829e3452e660b6697a5be6cdcc1519656df7389580d',
#   313: 'a968bd1bbd56f0370c4b23290f48be58a19881e3bba258a524be2f7fcb85b101',
#   314: 'c86728f3c3c99a4a2b1a8a4fddc5cbfe35118471e0f65ec471dc7de386d8e0d7',
#   315: 'c1c6da22bbe2ff9cec5543aaf72afd72aca7f2155d176033777d5bc533cbda2b',
#   316: 'da3dc7e2edecd18ec19b466e2f3c3fa943919d53cb97bf5b7e26afcba40621cd',
#   317: '3fdc459df7085b88888c05f91cf9b0dade43af0af08b79ceb7b558feefb2f59e',
#   318: '6ecb3f6d5caa515fed47dc2ebf76d005c1397a33f2999062292dd81f311d3fad',
#   319: 'ef1d35162b27d6f732b6317582af3906beb16d8aa1437205be3c3996bb0903ac',
#   320: 'ffc71507596bdbec5abee97e2dd43bc5942d06c5331c85b418ed6e4029a4cf6d',
#   321: 'a15b9ad095d45aa122a0a7cf396575b2ed60bc79cd0d3ba4934dbbe4bf599871',
#   322: 'e02ab4831b9b99165b5e347193b4991c3f5ebcf0a676e9b81094826021dc1952',
#   323: 'e07a4f694cd1e59a30b2e179cb6ba0ec559659ca3e53631b46c8a1aa09a736b9',
#   324: '0eb3b2f170e46e3ac61a5e6e9fc96a07ee83fd60b2d348722b8bfe028ba5c943',
#   325: '3dcee39ad0bf9596c6ae929549404754987ca102ba313c41cfc72e5acf2dff96',
#   326: 'c87fb284b6e738a3e10f82f4d9bc28cdecbbc9fe5f43bd6b302b7a738407af2f',
#   327: '4e2a2e90b8f407c4a4645b5fc7c54044bb684e2c345bf13a3d95818050f3cdf1',
#   328: '5f1c61e7bbce6cea6321f7c7076fe58de5fab3218437dae8121bc1c201978e0e',
#   329: 'add71172c9f1cb0cec47eca4330dbe0c3e22b7adcbfa876d97a621555056840f',
#   330: 'faf3d8a79818285a5c3ae99f27914344c64c4a8678f627e608b32d936cbe2fb1',
#   331: '5ab42eee4ed6c57ed3d004ceaedbfcffabd9f0b92b292de66e0db364685c3dcd',
#   332: '741702c8b391758d36c7e164a03d39e2e62aa9407db0ef72cd74f3b1537231d8',
#   333: '551961f4126e142bff32091fe818618360a3a67175d10644ccf230b523215659',
#   334: '86532de1cdb135382ad9c6b048a1d3b04c8ff17e63087b1e86e073bbefee79e5',
#   335: '3e51a34767c77459b3844375b97ccdc9d656dca386787040784cd6f40eb52746',
#   336: 'ce89835ea5883fc15f03aa07b3ef311206536a4208611f43a6feca4603bfd68f',
#   337: '3de9daca053f18ca9ca64011d6bdcec327eb5839293a1cbff43c512dfe6bfe88',
#   338: '1ec690a3fcbefa061c6d8adedc476abe68cf1f34ddbbc88552e6f8eb4f95c453',
#   339: 'ffcf8584b93f07de4842460d73b188d22d1687aca878ed07720f9bfef69bb11f',
#   340: '58e90a83970a1f49b35c45fe9dc8f1f5ddc048d7bf7d5f69ea8ebcd28703ee5e',
#   341: 'ca2d075b10314ab310e5d3eae1fafb2d04d4d275e4690890645982f01400eda9',
#   342: 'bbbc895c79ef69d9d9cd26118cbfe1a2d949441a807efec4d74c6485ee92b0b9',
#   343: '4ae2a0c26eaecb025caee6e084d7617a20a1b6669aa14132e2ceef47bc691c63',
#   344: '7326853b54b48096ecd906d5d7e619e9ee5c56e8a6da65d37d3af75b68310cd4',
#   345: '24b394b402eeacb33faf5cd6e688e050ae43ad3a4ce0a9c70cff1f81bc3d1d80',
#   346: 'f20fb6048ebdfd2ddbc34c523058eb4ae275f59cb186938f35a6f0ee12c5aa91',
#   347: '97bbc026a568d4d01e5f38af97e1c0510497a43c9ba57af3c3c652d5da6f6842',
#   348: '66c396fd1aa23648b2f6814d57f74c2291bea0e70fab13e4206574a4a939f586',
#   349: 'f8cbdadf1d73e34e5370585e9204e8d79665cb22ee635a3c444028ba29924e30',
#   350: '44a4a3a36e9357617db94d9b9ddab1b5ebc11fd29024931e43f8314de7351a61',
#   351: 'be71c475bf10639d7da2c93b7f1e65e75890d0735e6c08e4ff3eebeb7754485b',
#   352: '0cb1062ff7c4061396b0163424aa06d818c6c884a9061aff406e249546630f72',
#   353: '35200df6933d1f92f8a4dff4d8485f68ed5cce9a42ae0dc59d839a02b3a24d88',
#   354: 'cd1e46b5054ad0c6b5560520df9d49bbd024bd1c1fca32b736c228844382040f',
#   355: '34ef5e5c3bce029aa3eb95740579cf12bb35d78e36619bd31770f9293f83ea06',
#   356: 'aad38022bdfd41ab3a82603a62a7d3f13d84d79de3683cdcdb8369a81c3bb3b6',
#   357: '27cf98e6d9f7f46fcc1d77858eca956f4e4d28abcd5c2a99f63058b4d36f5514',
#   358: '01ad5afcfb8a6b0b488b3c5fa51afce48840b4c7c09e3a0c3915db925e341f02',
#   359: 'c948533b2abe44ed5a89737ff222254f12bbbf9e411d540b6a9540d20a00224f',
#   360: '1ebbf0ce56c2699238b6963543347d1214440bf073dffb3f289a0a4d60f34f22',
#   361: '75d20321e6da3232768248d29c6ae9031500409a516016ba732dc6b000d9b2e7',
#   362: 'fb850b9d9cd074da289dc2fc9ce4786128507a0c70421ba8ef9293e315515be0',
#   363: 'a4f107998f69cc7380f8dd00bab7272eb88c494704b9599a4be8cefd7790604b',
#   364: '36967c088409c5a210a9451733a7fe88a0c61ed0a6ca24d42953795e831a34cd',
#   365: 'ead868cbe7f47b0ed8dc4e4076b381c6d7e18a6945a04a921db73980bec57496',
#   366: '74dfd83cea5279c5cd18deff8311da9eea607793f60ccff90ef30a1a21254988',
#   367: 'bd6fe916792ed187cd20a9c9a313d4a5779597976ce8e1efab256cd3a3cd473a',
#   368: '13d3a6f8658b7cfbc0374481305902250b9f09a1baffcdb40ed5d0bcb4ddd85e',
#   369: '9cfa89348b85aaf5acf161d81b1721e4f13e383c27334addada7e8ae567d8d07',
#   370: '56b84535a5431b21c55571baa660f6e65a04262013328f876b32f82639c2fcd8',
#   371: 'eba374a2a08ba873437fdead876de93f5671fa4905710542a856ab5a9311c053',
#   372: 'ffa5701d0c3d4a5facbb2dfa9c67b60d696caf0160c9a3b773fa12e4c42819a7',
#   373: '40d2fbba9bf0a8c30387cd18fd4896013a2d5330db1f8ba009db520950764db2',
#   374: '710a0599071bf7855fcd71d3a1ec8f0eab7634d7e47cd0f8bc37175f640a039a',
#   375: '18ce5ece321c265dd45ee594bb3a97869fe05d3e6d52ddaf0f23d307ef9b3f5c',
#   376: '13527fc296ebb97f90e91109605146236832fcf8d3bdb169413d92b61282dfa8',
#   377: '14cbebcb750e96baf0e7fb29d093d4de1a2bd1ebd84be90b7999f9c50147c48d',
#   378: '22b20709c2a180e9b3b45e79854a0f3a125fb33ae6bd9178551142875aa0d3c6',
#   379: '94d9b32f7df53a76ff597d2d1304b1e58a0ed162c72cf8268b107ff648a5ff53',
#   380: '753b4d2f479a394859e675dec163a535116c6fd2f94dbc92cf39244499fa43ba',
#   381: '02918522b2c1538b2d09a1420bef3aa9a6dcf50d31aeaa651eecd5fba93f748a',
#   382: 'd71cbea380b970d6cced0ef3f686aadfb27cf96731101e16db80d0b875ff389f',
#   383: 'df813329f73ee08571965c2625165b6cb1c596b80537704dbd574b7d76d337e2',
#   384: '5b40760dbdb69deb0aec5577a96f099f32592d825ee0090d178267d88bafb6de',
#   385: '07860965bfc10a445ac2eb18c9eef472c2c869baa1984c3df31dd69592c50218',
#   386: '94159be43d59b248506530503f8361fe0bd9c3795d99d272b86351ab92fb6e20',
#   387: 'bc524149f19cb1ecdaf0d272d2617faf183fb3cb2f4446051e9e7a4d0e1578e2',
#   388: 'f9f89765d9d61838c41591fe43283ad73692a4fb3a313cb0abc0951c99d307b7',
#   389: '25483af5bb4fcfb7ee2ed723e287239a32fb4b98dc61a522442333e620d86dca',
#   390: '979f6877c6e102c96e46924a7c3e185cab860e8be18aedadc7ca6a12ecd3b247',
#   391: '0f8eb5834d59fc97f9f5f2d8c034bedf9f93f76ce9d86a063b637218b42ed771',
#   392: '14443f9bb96dee1981bbe979993936da113d1d21df1642beb09a3804131f20e1',
#   393: 'ecd08bd57b65f04b5f83d493db898b9ec25f6bf304a26ced60f5e8fe3d4a2dfb',
#   394: 'b381038bef1e9eee64a83b9ec961028e13f80a221295454f30f6a8fa76cfce92',
#   395: '8221341fc9c86016ec94433a25579e7d4248bab76892a2b16642dadf2bb935f4',
#   396: '2df0c45f108ed462be97bf40d23056f8f810b9381ef49f71e0af048efb610380',
#   397: 'f8152008a3b24905f465b378a39299fb72607c79c56c6717fa7bd8c692fb7cfa',
#   398: '79745ac976620e1dd37a1ebbc1e8427d95a2851548ff4b890351e107d17b6970',
#   399: 'e92034df6c3ef439a68350d32841d3c2bebc859d76a8d1b92088771889d37e88',
#   400: '455a1990d63531d25c5696a0935b2e2af439cdb0dd386df1e455249c5f52aa13',
#   401: '6d7bd0cc0ee227f3d1d30c3f5d1c155de678ee0a26a28c380e9aa717f7b2f8c4',
#   402: '244f0c39c6b32628b675160aed7c83b51defa02d5d0b2ac4e0ddb2ae3166a457',
#   403: '3c8ee465520ba75fdfbee98609f13c85da2d4fb80a249f4aeaee6062c1feec8a',
#   404: '58e9e1fece6f4d2104374d7a489a810c56e923edad3b92528494837baa9141f1',
#   405: 'cdc89325983316ddf3bb585ba7efa02ae1f275eff0907fbd6dcf54d05c0c675b',
#   406: '065d08eddadccdd4e7b73804bfafd34c433e5446878d4e6f1723fcbb7e41da89',
#   407: 'a8ffb4703e6b57a8d09c86fbf2c7a40be77e2e2345188817d6bd4990b05c57a7',
#   408: 'd47bef1ae93debbd1232c653dd84e9559cfa93b34270eaee0087d55ef27fbba6',
#   409: 'c3a96c50f69e6324d0a09f32b8abc94e55df392b269ef97265c367ec0b6db5ab',
#   410: '36490fd5b8deb431f3b1c9fe93442ad1b26a1f17498da4d7b07ec54003c137c9',
#   411: 'af43c86ab4790dd6dd9643bb6281b37dba30b75285b85b7f359a2ae8ede557f4',
#   412: '2b36305adbf2f57fe276933b3a100ba57caf363a95a1c2c39c8e46adfcd30ddf',
#   413: 'a81e85ede73f3fe133fd5423624577ccbb277f280685d7eed904f2e3443abd8d',
#   414: 'e52ebf508859f429fdd9c80ab7d2d64760ba7c8aef9eb0dc81f3fb5d377b766f',
#   415: '7c897b0bad27d3c9e0b20fd1b33926318da528506929d6756417ea3ffefe1ed4',
#   416: '6dc0079276f74751bcd19122d534185a6daaeb4d7cb1df07bbe630630355ca4e',
#   417: '3baa55c2db9cc4d5ea2fb72e47b05c2db487709f2d317314cefa65cb474e4f5c',
#   418: '20e72d586a7c7e4acf0f5f52488d3a82764d310a5477363f3e6492e12fc3e42d',
#   419: '6f075ba9a5c8f7c8bfa05c4b1eb97079012ab842c0f32bf67f91638c454b9255',
#   420: '3b822fc91f028bbb4634bdcdb20ca89ac7c8743fe89c12816dbe6bf975630d26',
#   421: 'eaee6859814b751c83cbfb883396ec05d51c0e53806871f8f1f8d1f09405eb37',
#   422: '8b94a6a79d4aeb47b07200cab59178703d4fecc40f7acdcf7f80e31d4a1d5848',
#   423: '94af6d929948d101683acb3956fa12baa009457ba28c5e5cbadf5076c1420da3',
#   424: '4113f15db37b914c1de4fbc0b163cc7e9a30ce118905a6a14ca3c62f0197131e',
#   425: '331ce633c568cfbf2b259028686b64a386d4a33edff9ac9f2bf912bd18e65e73',
#   426: '2dafb7234bba82c777ff7f70d23eb96bd8e72280efdc2b0b06e2eb3d74d1b298',
#   427: '725f02ad82c8b8f2d701272538571b0bb512dd570cc7e714173bb9154a1103b4',
#   428: 'd38c89ebce642e0da53c49f37ff40d78c294b75b0ca8a484a1585657e8c3ef56',
#   429: '8e2c7d62ef8cdb6db598bc0c629586e86636d91780c2e1de53e96202ba3fc1ed',
#   430: '374b5de7e812ec5b3f9e6afa5c44fed5d0de2dd503f2cf5298b94b5bf9eca50b',
#   431: 'b29a2cc4f1e566405581cd5f60489e405c5962e9d8e8af1635c56a550ffca4b6',
#   432: '6970f2def61b92341e5354a02cf976add28cbbd6ee9f944ad0c48038bd4fb3ad',
#   433: '06625c3e93d6a5f5eefb97f099b1849a9b7abe66c59aa9fe10cedcc015ecfd16',
#   434: '4592e0dc87d9515fc520f8d77f5f2323935513d8e1050020b472139c751ee1fd',
#   435: 'fbcda355b11b90223deb285b845b284ad94af3d6dd5e4d6e501f6d3ec0dfc866',
#   436: 'f9bf6d502cf9837bc72b46cb8cbfac89be77f7e8c5467379bb24e20ce4d5b22d',
#   437: 'ac1df7436343233747e986683175f664ed5ef03a7cacbf52fa60d41395a55607',
#   438: 'f3979e5a15df0dc1bb3680d7566e95c94a71e9cfdebe7d40316f143bacc66a9b',
#   439: '5592563e41bfe8652650339b0ba18e10f1eb3a7d509ebef9943ab3362a99e2e1',
#   440: 'c5b222d1f1f5e6befc41c3805dc694cd04473524b534ad99cbced93ccf2b5940',
#   441: 'dfcaa6cac509549bd7524f15c45640907ab53feab6a04a1ca4455282459c822a',
#   442: '4229e4639cf1279c345ed3b7ffea86bd6847fbc1888073b52d00c9bb194ccda4',
#   443: '009575cfe984a831360e2ef7a4df2a64c30649aaa9daa07e94011fd24a744504',
#   444: '480072ee70e39842f54a698a3c8051fd43ef5de1c942f57cc324744bde2308a7',
#   445: '6de4552c75aabd2d61122ec416df14e52ab1d6eca6949403f02793a3e1f5a647',
#   446: 'a79f38caa0294df6df1296c904cf3b18f61ecdb5ce1959d4b7e61645bb4a38c0',
#   447: '9e02938510e79be4b77a94fe5df95fb098ab5f1e1839798229cc1c986e911eb7',
#   448: 'd6796839a2cdca249ea4c781d1245eed1d5c6d58771852466b2188b170fa5f85',
#   449: '1fb34977136bb2cfb6ea2a2b531f4530b6a693f3494c31f4872b6eb8fc2545ca',
#   450: 'baa60c6e2813899d8ebc888c5e3974ef749ab8d25a6fef3bcbb29e26c139f33b',
#   451: '77fb0e52f2d56a44996b7d0baf0f44f6807fecbed8d15e9b01acbe6dbed786a2',
#   452: '37901551c069148321e4b419c6c6909b772da907208b2b6c325fdfb2eb51b112',
#   453: '03601346d5f231ff21860cd301a0b1db1f729427b6ca49cf2bbc0c75e2577cdf',
#   454: '97e3ab8a026407bb79e2d29d21a7590611e96b8a0732b8208a6e6fe9b02d4a8d',
#   455: 'e24c9dce370d20043b3ccc15adcbd93d341f781e0523db8ff3416effe73e9a41',
#   456: '098d18b9ca2162aa27176db273efd71c15cb4b90fddbbc2bb97242aadcdaf167',
#   457: '3d0ebaaff9ea16e19df9923446998573b3e6b62e3c3fee2c8772ee37f0d9c4f1',
#   458: '076adfb039e2a486bbfff8ea6368cf46d2131bdcbd7d3a8651925e22efc3c500',
#   459: 'f05a475bcfcec635e7c6484493a24dbdff846c4cc6bb78f657a95739e67aea71',
#   460: '209c5c287f81bbba4f2a9f665e3b82c27bab86b81d0cd038c6ead757a5d9a871',
#   461: '5b8411d0860ce4cda0a19bd705c9c94bc332bec7f8742c64a7b80355f34e7bcb',
#   462: '7742b851b2d6b5500ef33f473b446bc87b1dae55a73194f1b4a6ef62558f052e',
#   463: '43cfb4af5ccfba9707e9128013caf15dab022a6d535571c472f417351dc9c979',
#   464: 'c7c4bd02e05428c45469a2ecda790639fd41c396bea0d60c8d27e4d4f910cb70',
#   465: '5d87c4b14e102934542ea54c62b902e62af46a7c145b0dcecf6cbfc46e3ac3ca',
#   466: 'f10f0aa8bfe5ef45806b00823c4bae08e1133e88bf7e8bff33954e77c14bea00',
#   467: 'd7518508e2f226d44c58631399ac71fc0e500f74230ada0a9b326f990ca0c0f1',
#   468: '4081fd08fcfb0c9e7501fb9d3938407d6a212dad21c97a6a0702544b8daf401e',
#   469: 'fa6c39a3c41a843015f2e03d8b4eb4d57e881f4b18bae8a2c45820d02cb101a9',
#   470: '238ca2ad9fda14cfb4dfa7314e6581f57ffb701002d8235e52650f1c909366b6',
#   471: 'eabdfbdb3e723fcc3b67ea625765d0ae355492f00fe77ebdc8c6a8ac17d81367',
#   472: 'a104dee8f029e84201d29f0b4773385870f05cc44213d083099b95490961150f',
#   473: '0d9be3faed36ae9a50c914879107c29e9e13a0cd259e0430e39b452742816c70',
#   474: 'af80f890fd270df93de5ee9f5aa867a84f4ce4e754fcaa332906ea81b3483cc9',
#   475: '0160c0c859cec8b246f932c3ec5580bd65522fdebeb7a4efd9f54488f2bdb334',
#   476: '2073141a675c32d7451b6fdbdb4b55011da4acc44abad82c22dbe518e9a75959',
#   477: 'dab336b28cde3187c0c0cf30f6686d0f8faf7c72b53d6d0382d8b04d653e9db7',
#   478: 'b8ac1130c722ce0403f9c58cc11a5c9b078ac6cd48be0c92f720437228a76e74',
#   479: '005252caa80cacd8938e6584bcc1b1f3b49c9ddef90cbdcf7514490103423e22',
#   480: 'ad227e2149e191510531fb0b807ad53ca8d8c38908e3d5525851aea581949112',
#   481: 'db899b1cd1593e3cefb1920245bac20f888926f5821c513e42f1093da69198e7',
#   482: '31103ac9baeb79df4b80eb88b7a085b8083ad424ad686d4f4257f18a4e5b9e4c',
#   483: 'eaec48bb1f49f0bfc996c372b9138b701ca7bdf970828fc4daf5d980a678f619',
#   484: '8b526c3c7fd37ec30424ed673e86e2839746f788d8e68944e275d4d7aee80ef1',
#   485: 'dd7d2af4e0396bbbef02b06e46fc92dca789c2bfd4ffb64dc82a13c0155f287c',
#   486: 'a0ee6a882015567c92fd46552c77ffaf7628d0e26906feb56a811c47c7f92bdd',
#   487: 'b2dd0f94fbee1b4f562afeed561b8438c36edcb1aa6050181710dc030ae84435',
#   488: 'f71bee5064bdb4fb00cb574816bd762f1cc498c420e4ffeb20225bb0c78e5dbc',
#   489: '6befdbb90d635e922a1bfaa276a5138f8befb71cb5b0fc05f710a6bf0a6f877c',
#   490: '81589e98792a3e987e38f92beafd0afe8d5c5b51b204af63b5fb62d14fa4d32a',
#   491: 'e293b8e454ad6e34fbcdce1b3194123a3b998ad8cc78cd30957e1c83d7886409',
#   492: '72de370be3efb068aeb51f7cd636e7c8c84ad21efdc607f3172073d5e641a134',
#   493: '9525231e58723ec779609399ddeafc95a43ed404678dfb3ba03c0d4cc61de979',
#   494: '21093ff4ff972e339b911c61c54d232d957e38e67fe6cff47b24a56a2386b0e7',
#   495: 'c018a3a2b28509056cd5c6fc521cf122f734325a605784e40b0e72c1f695837a',
#   496: 'd56639646439231f87061a3f55fdb80ec9e0854c3ed4ee5edfaa384e2462cd5c',
#   497: 'd593c18451c1b40d2ff0fc6e2eb8fde6272ee06c84ad78f46fb6ee322965d237',
#   498: '79c4db4cbf470d09959d87d47f7f8c3b7d65744bd485f66dc753ab5ad13796a8',
#   499: '1b9a28a4f28068f0106a5cd47b4f4fdcff6ddcfbdfd732f8bd9f2d6fac9c03f3',
#   500: 'eefe2db0c940bd22de328db4e9ae6f324e6f05217a90018416cf9f7f7785e463',
#   501: '724d0353f7fcd6ee6c35814efed905740801feb8e3fbe21955b65f36558ad24e',
#   502: '36ee7515809236070ed6a0ccbe9261ce4c3004a7df4e86ab740cb48262feccbd',
#   503: 'f11cb89557bceac7dc722a7c98adb78c2b4a00e59faaa31fad0d3c66a7f89a4b',
#   504: '8f3236c853ae6b542cb9510a374e4db62d49b14c12988bf24098ba4bdda808f6',
#   505: 'a7b1a2b662f0d2dc63db2ff9b47564ef57a38398cd1da30ccd514b506cd0f31e',
#   506: 'bbabeda1a36aa82d6a0defb5cf4d46e47fa723c7f3dea95ed07c49cd6af2ea70',
#   507: '1999cfff9fe48db9abd29565e90678f5320289249c15218b957eafc660e91acf',
#   508: 'e6cc7da257f5f5cfe20bd32c984ebac3a93849d26d2ea16b50611d559af488c6',
#   509: '6e4d527b9c45aacd776b975a5a23eef3e5398dbc6e62b72890b2d1ae15160e4f',
#   510: '6665233a414acf95d01efaddaa1811b523eaeaff96977a789e40027251cbf53d',
#   511: '7b54b852990847955f27b03d715cef278ec8ca4aed3fb95bf08b0b05f7465ef3',
#   512: '8f8589768988713b7495f01911181779d03519905f9e6b9c2380ffe211624581',
#   513: '3eb8b248a8a79c3700959dc790bea943611f80e8d2f3d9f3bd7bac25ec04aad9',
#   514: '874ba4c1342865a7b94e32bc14047439bf735d3c3c687e2d5d0476e2d5f1e74a',
#   515: 'aa733295a058046e02dc180a8f0955909df18869fd8526ddddb222e721ee3c85',
#   516: '7e66f4f7380e316a93eb4ca40649ae9abfdd3e7d35164c55abb73e1ba10356b2',
#   517: 'f4367d863ec7ecb363794c05798d20962c5d7232432cf7d2a1956585e1eaf542',
#   518: 'ea63e4d09705f1ab9f209d41f542650d87f0326b9e32cba4749feb66ff728f85',
#   519: '41b24545f37c6ba43dca6d1d62b9caedbbe13bcaad0f6460635c81859e1f81c2',
#   520: 'e6563af047b5b4b2322f05c977573d4390196a3ee684f51d39ec840ec945100c',
#   521: '6047c1187b92873d8ce954f99dff8102db49c232d667df6219f535ae9889691c',
#   522: '518d48c3bb585383ff0e3ef7eae9fba4606abe123bff1a87bcecf67ebfcdfc10',
#   523: 'efb090e73cb5d1754bfec60d87bfd8243a5b75003a72121e4b2d622bebb9c855',
#   524: 'c0800c5e7bb0de96cc4d92b8f5d2143c4205706fe411520f97b7de9d383e4968',
#   525: '52fa3ed535316e3f24ea3acc25f445952d10f175321b80c78f2d254a23a65ec0',
#   526: 'cf6b8471a72b270aa03ca132c6b1760edbcc2beab4ed8a503c6f10bd6ce54629',
#   527: '9c23bdd828f886a770c0affd3bb0ebaef80003c4e85771e271523d4c2e3f5964',
#   528: '6ccf24746ab97d9dda9fabbbd9f155007f77eb7b4d76f944471511a6d0ff7872',
#   529: 'fc0e2062f231ed129304fc20cbfdbaac34af5cb57317d75e88df1bf8eb52094a',
#   530: '30110c9048cfe453a633a414538920f588c29925b70812af3b6f74d7c1f92abc',
#   531: '4ca02ec898def56bb3a6e80b5bcf9fca0c628be204c7f293f10c131704b48f7b',
#   532: 'f1d9beaa1e5381c2793fbe31879c49740826e02d6f05826eca72b976492188b4',
#   533: '4f343f73faf6bb6820c527a3c639198c614e6c4c05f6e761217eecb6c35b74bc',
#   534: '5bbbec250716129a0845dcb37e7ce4a5e28e8e5e2fd52356d1fcf3f82403d8a3',
#   535: 'a1978c997211d67be94e59eff62777d9d0030fec29c6e2bef5a646dffd00827e',
#   536: '366c36d24949d4b7c5c5ab50225de01a201914494013bd0c0c0f4c6f5a6852a7',
#   537: 'f56a15332419e4933ea6d2fda3017b9bbcd04f7e34dd37e948f6f3dcb2b89f36',
#   538: '4f838ad9c2fe1e90bf15b5cc79168bddcba7afdb9d418e23e12d7d43586fe06c',
#   539: 'aa01bdd95165775b3224c0e429f97911d7824c7b324192e88a7ccd8ad20062b4',
#   540: '8bdf6f57512d0a5f1e5973667f1572262b56fc9ec69ada50a20a5ecf9293f2eb',
#   541: 'd6f09a7bc2aad049a6f0850ffa08dbd8aface8368b641a18c4224a7878eaae17',
#   542: '6470c36b9615e4c04c590b7e356f9bacb632cf2aba3cacb6ae70f51c176c942d',
#   543: 'adee9fa45e99c58a0990c74ef5dc6b1071beba687bcf474df319621e19f857c5',
#   544: '2d2c335977a751a4f12a77993feb4f0c2f35aaa1e2d23ea785d7228e337f961d',
#   545: 'b01ffbd3deb4b82250ee501da627253f3ce26d172f4efa04133f70693dca87dd',
#   546: '285ded8bb08032aef00afe35902cbe18540477aa7e3dffdaf8bbd4f777a40381',
#   547: '31f4fd68cc42d9a7dbe71d779d953dddfb28a0773376eee3a57bc9235c79c34e',
#   548: '7d740408afca89b2a3d25492dc9de0a252310aabea7425e208c882773e331c8f',
#   549: '4baec228ceace8ed64daacf809d8d23005b420a9b8cbcc9cf05ce4885fdd16c3',
#   550: '05b9b10a81cb983fb642a0ebe373fa4e9e51f7acf231f2d82cb4da85e2a90aef',
#   551: 'f4538ba113c9007c23757d5062a69b204e6781dfc3eb0bbdb45bf1f3d482989d',
#   552: '4018740c0f4b30eb30289dcfbed02e8fcca77743bf9bfc27aff46a430d76d536',
#   553: 'c967fe11ce26bf5433cf140c2d500f47a8c9baed128f328622307effc1444271',
#   554: '398a3d73eeff01a3a606920198e455f6399afed6dfc8ac87794179693270686c',
#   555: 'a28d9946d76af92d32148955a8d5380d8ccf28efbcc8efe24e27e090e1da8a5d',
#   556: 'b053e2e5574e9793c7f77613f4b75db8b3b91494d9ab40736d838de3270b92d4',
#   557: '09046c0c47fa157f8946d3df0580d994c69df667eb68038e8ab7edb917f5c977',
#   558: '1d7264cc02f2d70a5e88f6fb1fed80b67fd836d53f1b96f6faa496d7377f1c32',
#   559: '48ae0c0ffc08a71fffb640b7334d953dd2c631b7a4cd534b2eb44a5ff9a9a1d8',
#   560: '5b6d8f239ef8fbc6141818cdcb45c1be9089b7aab802b9ac13e1f5dcdd7e9a42',
#   561: '11848867a1d6264a8ff848dd9105a7885b343870a596ad63ba396d70e7713cd6',
#   562: 'a063f716fb5bac3697797023b175f74323e4b544845cf8e4bed6ac18a1b6732d',
#   563: '4c8b25e18d5f342d214393d7f5090418c98303524a11f6baa1effbf33659c877',
#   564: 'a3fff35a58fbed27034487425f0c7d03c34e44f9bdb30e58eccfad3c7fd46041',
#   565: 'a79eec1e94af239dc168edb6d513d353c3aae685ef5f606a06a0932aee730847',
#   566: 'f4684463267f1ab03bbb313cf9b033770fc3a6622a54e6c48322a86b44b9b912',
#   567: 'b157ec372ac3ee5f2df5c5e66e8342d9cd34e87b1156fb49159dafe9c8c481ca',
#   568: '271546f7f2ead4da9bf58743d084fcdffd4a194ac04be900f53f14cb52d29b2d',
#   569: '996df02e2c51f91cd1de51c00555b560fe93a705437fe6f7c08df4e9463f3adb',
#   570: 'ccb53636adfc188583c4e6baf166e6989ff92375f7dd6613756647bcfa0a67ad',
#   571: 'ebc5c6d554bf2fc17cdcda26b7c1adda015943ccac2161cc6a36e6f1dcacb75e',
#   572: '087de13287c78ee3de5b51e5b5afb9f5393bf69d632f1d4dfc8eb8b011e90b90',
#   573: '665844e6c27fdc3b76428233ae3726b150a334c99781351903ba64ab23da10cf',
#   574: '5559814a6d09125904f3fc1f634d3fa2eeee3176d6b18d9dfe7744c893833c3b',
#   575: '8b1b0bd839f7fab7e8a58f641aff9c716a48166d5446c3bd4688fb4ca55230fd',
#   576: '74ee05c85797255cd3af158e8473fc40534fc8ad32472bea09037ca720adb349',
#   577: '7697c1bcba0ca85954a4eccb04486c84dea88d07a28606099e8c6a0861c6578d',
#   578: '40f25bf68841e633ed5dd73939b6807b428b5557ed86961e756f678fa214c06d',
#   579: '550c659b778e170a2a7ac8bcb0d15af6e63c4d9ac3e399d6a5447f3a0d88dd59',
#   580: '0592bdbc51b383c0cf90ed132e7956e66103b67ab8c653f46679b642f5c43814',
#   581: 'f4a81b0ed60281c96600b3820e24a2332fc3f652ce26b0bd96032423f27b0b2e',
#   582: 'f958f7a2b9e1307d49f87dbbc0a518dcfa42beb5ea223168683deb8b1ada98d0',
#   583: 'ff0c79a4b5f9584ae92fb908c684cfe1cc1d582f74b5b9b15caaaa9a403a6307',
#   584: 'e80df60d6013329a77ddaf0883f9d4f4633a00f804191b0dccef7481df21a0de',
#   585: 'cfad78c474e7fb3c619bc1b6baa5b9427c787ed76ed3ec4cf99606a16a1b592d',
#   586: 'd02840949aaab7684f65f3b84e7619dc57d83e23112f513299613fe6e6d7d411',
#   587: '4f8b2938bc5cfc3f207731b97ce971779ae18af0e719ef83d24c6f89515d9874',
#   588: 'f1e4a0d98dedc62ffa9bdd02610fc34fe8747ee885b307b40976ff3326f5e73a',
#   589: 'a7938b17017fee92b0b1a9aa879c74a2bd8ec4d2f92f25177755ed7dc1933630',
#   590: 'dfce626610764409b3a4de3b83a7bfb3a726fc48547e0ddb5c83977ca514613e',
#   591: 'f898a528743a1f33f181d8d158916c1c8ef2574e71438814cd53d08324dd8531',
#   592: '52e581505249b16ff7131194f94b4fcbe81078ad5c73bdd4c5d8926ca87e6115',
#   593: 'cdef0f7f9ba22d227ff0bb47476ceb818cd4b4fefd687cf8e1c43eeaaaf43e4b',
#   594: 'dbacfdc7bb985ae2c1772b4a0ed48a059637b462b19263b69ab62d0e00196b3b',
#   595: 'c41baee47a5aee7b50d7861663d82e6bd3b4e2cac9c925dfcb9ef970c5a4748d',
#   596: '4eadbfaa52cdb55b183ebc181936a95f57cdc6151f4d792f4ab8ebf96be1e94f',
#   597: '49b0fefbd965a4252c103f936ca1d0e41be747cc935fe144146c03534c16f970',
#   598: 'a2189997a997bce3b522d7fc5836cd3a288fd3530a8f0817a65216708ec5cca2',
#   599: '8dc38735dae938f74777f7e143c72e92c37d0541f2ee621a93a6f0b5324c7bb6',
#   600: '8aeccdb2e5a3c162c0ddec577c1f197fb082d201075a5f9cc187086ab5c29f1e',
#   601: '77b1fd2d97ff00f67a98c1c1be038a473daf4f8dfae774b963f3f6911798ca62',
#   602: '59e5003d4a0ef2eb18df2840917c0411856ac11f97b5aeba5a98f7882b13288d',
#   603: '0655273c8a8275ce07026d5f6ad2da766e5126d9a388fe6651514c7b2286f62a',
#   604: '0bb20f3f5c3a5c20a8e51893cc97bbba2007813c028780a1123047552a6bff6b',
#   605: '788c8b2abd4e400df66eab27c8d2895cb81de297019efaa7edcb2ab1d0d2e1af',
#   606: 'e4fc248f38dc9ba80fdba0aed709e1b447f254175d5fe1fc2eb5961823bfc784',
#   607: '48c606c36d37e6c39737acb575468689d6c4ddf4680c0ed6b341893dbed02129',
#   608: '2f6d3789bda92fab5bce40a071fe33ceb5438d9bf9d7d1ec497a89de4a9358ea',
#   609: '5d084ce635531f3c3f9d9d87dd4437dde01bfcef1ea2023d3a4fc0ac4c10296f',
#   610: '8ad1725a407cc97cc720551d88cd330df4c5bd5ffeb9766890abc42be65be759',
#   611: '6e2c398011e646e750c49c99c6d8d0e764fa32b552f2ae8134d0ad46ec56b43c',
#   612: 'b1cf13d0a9be3892d1ece629351522eb35086f7224b4dc67fd51497cc3f1e9de',
#   613: 'd1048c27f1f659ae5bc58bb49fb9c988a19c743b04fac8820f340bb17dec0b92',
#   614: '0eb0db9334e4570d5d3b83c28fd8fcecafba470a7d305f4f1a11118dd7eaca40',
#   615: '1bd0b7c7a249865e7b011043a158d2ff7f24c1a3417d95196df1deec4418103c',
#   616: '7d10ffd2d96494d39dd8dfd537476b467357dc078dd29c26694729a96806579c',
#   617: '457f308d7e51fafe588f259f33e7b90067f99eb74a8a74334383ce30f5d13b6c',
#   618: '65921892f627755f8790a0f8158da9ba733d053491448d2a0fe72d439e0fdc4d',
#   619: 'afe070bc56eb5bdae56a3ea54ec30225e6f6b1d0220976fc9b73feb6283ccb94',
#   620: '71fb33d240d27e98d334f77e38f8a0192d31790eab2af2777b6711f86f56e7f2',
#   621: '6eae737df217d7bcf4b73c59bce2b611c2432bcf83043a0815e889cfe2058db1',
#   622: 'e837c70af9eeca04ee34e5593d26a10324d1c650f58eaa4fe943e3728c99d0c3',
#   623: '1150db0b172455fb9a04c25b3e96b68b04390a9a133a95b2115c645ed22f34f2',
#   624: '9eb140951f2122e679e3413e5261f41be8929f7a5011c7194e7cf019f892b149',
#   625: '647db5b5e6b0d39c4fcc0f7e2d5241f348b9721f2f5b9e962a69a0e4d033f2c7',
#   626: 'df6c31d9898ef06aa6af88631343ed16d8bf767fb4c98b0bcc96833a99df992b',
#   627: '595e856c178b8cf813fb274ca172d3f0b313234830c21375351b9f8bc765c5ea',
#   628: '1076e5a9b4f2f5808cbd0a25f8a7f3680198a45f38fec3db35a25335ff5be0ca',
#   629: 'b090db6ddc85b69acd050591bb0e42e58fa861588cc15165b6bbe291f18a9e40',
#   630: 'e19aa40d15c64d6635cdae2cc6823a7c037462429be0156f8c1853e38048020a',
#   631: '62fd9c3b79174812a868a8e8f3e61bf29eadcc1babcbaf10a2f04713f1dd4296',
#   632: 'e872faddf13615f6d61d18cc164a04e9d75eb11b314fe6001811cb9e90613cba',
#   633: '261fe3284d7790393d3124bedefb9e90c0cc792a581088da3df5dd863e2fdcca',
#   634: '10932ec53a7a679548440020fa5fd1bee82a177dc53b78d3bb51955b3179958a',
#   635: 'f03dbee175257aa8e7da5506369c478d4ec3d3861fe5e37d710a28763a788621',
#   636: '3e22e1a932977d778f46afa5b10d8bec925ff4dbc1cc56f0b0d849fb676fd6eb',
#   637: 'b30dcf301336459228893c08d52e2d5266e1bcef7be624a1734b47a3ec76fb7a',
#   638: '7cf3dd25a11bff254f32ac603d0940555be9d2b9676ba12be4b0fe3dffceeacb',
#   639: '82f81141322365f24a980276d97030e52a3245bfd4bfd9a13c57cfb81c1b4e00',
#   640: '40b271767626f7a00f345a0d71cdc40963f41aefdab75e7d26b79a482ca3caa7',
# ...
#   787: '36a220c6655df299a5e371435ed7b20fa42d0e8d6bc0e37c16905aba049366d4',
#   788: 'f957dbfef38e38eca25d5e2db2410e9f290b34bb59b761edadf1e22c745b47f3',
#   789: '43e109c16c7f2d7e3057babcbce350cefd60730f1a56a611e633c8a145f09da2',
#   790: '1c272600900cd972d001fd89e1bd5620a23d6f0613b6ced6a7667516ee1abe2b',
#   791: '77ba77137ce8ea1c8c5e2557c857cc116b1194ce4a3a9286a3d2d3f686ea08ea',
#   792: 'd9e238495203637afe7377a4063837eba7da06e5caeb5c4d7ec14d9d52504d6e',
#   793: '7a103eff54da8a0be1ce7c4f8873762ecf48ca5d9c9c63e97d4d5e635f264128',
#   794: '2cbb06771ff602908a7c689883fa366e4608fa0d925a47e6f76b10d4930791a3',
#   795: 'ed7035be9a98630d1155a3149000d13950729a21bdf32f28f821510be688758b',
#   796: 'db15f9443a5dbcf59148ea338a528504df78679bbd457399e74d71f897571a81',
#   797: 'a93d9f3e276e610aa04fc4522c2e4cdce884ea43f11cd2a1da84a5934c9c085f',
#   798: '10ffb77a1537648559fb69105c3f0814f7dd1ab056d8f8da35af394c0fb3137c',
#   799: 'bacabe33049343c04c2fc663b74c038085ceb46775d9c089c387a1af7153a1b1',
#   800: 'aeae3e47bdcf97b00121daecc38c8c58b6cef9353aae5e08f01e409c8a4ebac5',
#   801: 'df2eb628924369507b4a53d2fe3959da29066eda189e0af91a18ef30e1dd8a17',
#   802: 'a98cd724c3ed89af43363d688bb70083f6b95c1c4efb66af10131c957cf0f5da',
#   803: '74dcdae94ada45746c75007859fcb58aec968e7b2361be9ade32e756faf1c760',
#   804: '15356371dd3cac3539c0056ea6549f84ee844a5b8db09a1a1d266ab77bfb5e46',
#   805: 'db0d824d2d3ebe3e9729ffebf92dd4da0938ca61c0144b01aca98c5964c0bec8',
#   806: '8f567cdea2fc56afa15f892c701163916a939b9378acfbb22495a89643a02be5',
#   807: '3700348ec6e2eb904f61cdb040b791b2761412fce7f8e3f2fda912c2a1a24acb',
#   808: '367f6aa227bb5a3051f45cc3c143d1a4e231516292a8242bb0ab1ff454aa704f',
#   809: 'a580e9267949d9df6696d67d6be36b02b9331991b4ff8ca15af22cfe1fdb0200',
#   810: '397d08bae00871750bfc68c27799a257760b0086217e51e7824d8471440aa4c1',
#   811: '6042944e0e59c2651388fb126923c56106970ebbc86fb36bd6e6182ec864f736',
#   812: 'd3dbc7039a2e0646cdc246a8c13b7f7c637c91ab78f8102c5e9d8da349b87d12',
#   813: 'edb0094f44dd447f5ec1c2f529f7d6ad0aa9006c7a3382deebbb9e8bea5a7a8c',
#   814: 'a844f37a61e208787803487fe2118badc9566a1eea95a0898bde5e07d7ffab0e',
#   815: 'da981a01b765e944dee0747d86594ed650a52c781a7f4c161bfc3795c4e4935b',
#   816: '7a64703c4d90382eaed479e339d70a3817c3aa99ec04ca03f09e0cb7d705747f',
#   817: '8b79c031f4bb404cc630d1f5ab4c113517e4c87c110d895e0b74808d35c5d0ca',
#   818: 'a920c464bcad4216abfb0e611ca8dd5446084bc45812320b0849da42a7866e3b',
#   819: 'cfa5b178ad48ba793cb27c47f2114ed4ec08d7533a7f584f1c20b0e6acbb11d7',
#   820: '2011dbe2ac5ae7bde5a0021ecc9aa0090b9165d573de424c0e5571a38efa3201',
#   821: 'b7ec223238a7a78d7e17610d74edf27d53679d9aef5196aefc3351c8c5a5357b',
#   822: 'e2b3e490619a012b9e7738e0d003ecd1152c7eb70bbced9cf0f4a64dc5dbfdca',
#   823: '2fc6f1eeeb30b5e12570ab7c6e08d57133c5d3ef38f0bb2298237f3531f96bb5',
#   824: 'a5434087967cda257a70a91f35778cece58fc62084f534a6ebca5f975a8cab56',
#   825: 'f74606d33636a52d75fd6426a0bdae0250e95555b0ce23ac42ba885ac35439f1',
#   826: '2249a69acf43015390b5d1cebf2cb32a3adcc561135f3ff2b5875ff1a199cf23',
#   827: '7fbcb92a976511995c76bb69ba08d21a11958d979b7be0e314a8a36b235d722c',
#   828: '16504e7e1d5c248d12eea14882954d21c07c2fcb5114257f3c2ae170bfa89873',
#   829: '6e288c89ea8f60ed75d7236adf5aceac1223ef0dc74f21d165fb1156f0a9f0cc',
#   830: 'f28fedf483e6981a9ad0f8bcdedafa2b9c96c062562e9710703ce799b3b5c048',
#   831: '0661a022ee291166b79581a64a9638ddbc1899af8cc88b027e625ffcf1edfcd4',
#   832: '2749abf7dd33d62bb86c7b0c5f9d3292764bf639647e482af7e99a46d72336d0',
#   833: '236d3b4b9b274bcee8b0e9dc25189b51a7d150b1ad46e2c2285c33753d0ce1ca',
#   834: '52ebab80b30e4922e932f30f2dd0de3a66dfccdc96c92133ce409d86262cb234',
#   835: '5bd326f96fb1394bc82144bb93bd0b06b7dc66bef54f92da6b0164a918984bc8',
#   836: '50c9ccf215fb491a15965b4322533b9ffb88a62e973aaf88c3c2b23815c22da0',
#   837: 'ee3689c2a15a206efb4819826882f0cbd2a772595eab6b0b106420e55c560ba5',
#   838: 'cdbcaea48be99258d9f79ea12d3c0b4fb9d03089ee53bdc1fd6b9bf738cda092',
#   839: 'db58b6c40698d7371bbcff35d085e1bac5fa439d0de31eb8e0da7c47d27cb2a7',
#   840: '12ef51247b469e0c6606f51c9e517f042a77c80ec8e95d0d5c286d77669a0212',
#   841: '92276c0e7bb9ff3855feadddb46380c2c3cf445ea798f9fa9ef1afdce0c2fef5',
#   842: 'c20afbf8424c50d38ae59b87b69f18e1e4d720a713e786ea3b095fdcf960e241',
#   843: 'cfc509dc4622317eb9c085ea15a64b638a0adc30965d262a85b1c00631cc89e9',
#   844: 'f967bf9aa2a8778001020608da9228090530b00a20b6276b4bebda77ca49f392',
#   845: 'd2da1a7402472c8a36e8fadc8cda7859219673a375c836cab213962fdb9ac8bc',
#   846: 'dc2fe299f9eaa675b1ca447f606d719e82d5df23f2c14ea846c7ecfa3778d450',
#   847: 'af99899497d1728419927af7932bac88313462888a0c31b7bb6bd5aa5383f64c',
#   848: '01bb027f67d5a7c01c724d658c1a4cef8ea0df723be77522ff4084b102f5bc80',
#   849: '864fd8ef5d29716f46a78e90d3f1e4e08440ff79ba5ec98714d93174e2545984',
#   850: '84b013a947fe077e45e9cdd35b36a5d88fa1e52353a8151ce1e1d238cd76db7c',
#   851: '0cb758e4e3ba6ad75bb72b53f9e0195c3d3352a7d6b8e92512ff3af767ea00e7',
#   852: 'fa2a1f0e64f8a75e0bd593b694b13084d271393d078882bb4761ae8ca9e53deb',
#   853: 'c0479c1b425232f28ac7c97975196a8fa4b0fb7faf95113da5968bc69b95118f',
#   854: '47969dec561bb5b24f8bc7fc48f5e93be8184cf5c867f69c2e5b20b0b85cb3dd',
#   855: '86cbba9e35606967d66abd62a3d1dd083bcbc976036de38cb593df5fd1b470e1',
#   856: '6b9ca1ca89c16714d8ef813f3f246fbdbf839a33356d9723999337ea0b18fd06',
#   857: '55d58fdcf9edbf86e9fbe14f6ae96e143feeedd8cf6cb091a1cff30df1ca0081',
#   858: 'bbee854bf075d5734b1be27a24358a9ca9bae47dce7f07ca0cc91c29f0b743ff',
#   859: 'c038dc9e85a158f4c50cd1e83279aa6ae61508dc42d102883bb7155bb021823e',
#   860: '9f195b57a935d3c6b91459d8788226f210312664007f61e93d777a929428756b',
#   861: '2535d19a939b623a75217af41117507a4b6bb057108fb9fd3b76a94a8986ceae',
#   862: '3d76b67ff3bb9632ca4bda6141077f99f5486061f139e3cb8f10c9abc83bc3eb',
#   863: 'fe6b364d97082add18abe1e7332e62b4d6cc6e8aa444392ff93d4da2f0bf6cee',
#   864: '7babf6094edb97e445d2f742fc5b3eedcb33c543482130b8d22197308eac0273',
#   865: '00e527348a4cd299a3a32b1a2ed7b06d2d8f54311b33ea57a9cd8c2e24a3ac76',
#   866: 'eb9399fb6590b9ec3c5eb809c3ea75f3c8ea68f3a7873824323945d31a380c24',
#   867: 'a2749a6f2512cc9cc5e4b55bba39b4c21132b88d9066368f0eebfdc576f4abad',
#   868: 'e2601a0f1abd13d304cdd2ffdd7b0c608c2ce91a9157e14f5add369a63940e9e',
#   869: 'f91c4ef021e276ab97f23158ca1091468d6591b0da209a5b81dbbf7df97d5663',
#   870: '0ebbd4df8bd0019119e564313762d0f32944f86b363a6d72a2b4288a2d1786cd',
#   871: 'f48b0d17098f765130ed146e02e3b4d65630caebb6d913b811af421dfbb3e1fc',
#   872: '540ba49b046749b8cb65a834ce56f04b7ad7439f3c4122cd51182fbb0dca8bc6',
#   873: 'c533092dd34505e2fb505d8935856a4aa45e341986d731ebb16c74f473d72557',
#   874: '0858ab9fa8465c3da1e67ecc6b96d8b4cd2efc72eeab2c813877c70508286997',
#   875: '875ef576bbc23837eb20215e1d80a3f0445527cf6e4db3f87ddd8af67df91604',
#   876: '9802b914d015972dd17f0417d42af480be2670069e1f402c48c44c9f154aa915',
#   877: '436c34f53786c7ace57fe227e0a5c39a0cb1ef8e9539518fef395a7b5d41b3b5',
#   878: 'c268e047f3d0f716f86d3bf4c3d123ca40b3e06ea79522972873c3162236b24e',
#   879: '8369aff7168fcfb563c86f3d8da18996bc6af5c8801243f6ca3f67676503022d',
#   880: '5619e12f0d1909aa7726d19baff7ffb068e9dccfe49d17fd0a3deaad8fea68a8',
#   881: 'e9e8e79623bfd1b18c2417c23d9abf71f01723472816cbd8bfdc3a8ba94815dc',
#   882: 'f288cc6eddefe88d98870543ccd1d1d123f923541bfa86a454d3f0c58e755c32',
#   883: '4a7606ae71dfe4a99c5fcd3aa05f7ebf8b4d3f30f67c9d761a83d80381863904',
#   884: 'f7016fac68caf2acd8dbf03a7e4072c2e4ed6466e14483b32a4c479d7c76ce97',
#   885: 'f8a3a5e3794a63b64a976fafa0551a99e9aaff2d6f81133f1e512b4637edea04',
#   886: 'e80db9edeac3796267b3384cd20111d5024de1cdbc23baec2e6daed9917a35a0',
#   887: '5225356da6ef0c54b3952a6abb162781bfcebd24d02e342da0c16160e641a3bf',
#   888: 'b64fcd8bdc59cbff3fe5ebfcdd4d5c77a9c151510585349873e82456f9350827',
#   889: '4a1dd101d0df348dd1dbff9dd4b70e10bc2bdca8788c24f9c4132bf7e7340ef7',
#   890: '800a5bd95d1b8b08bebf48960f2f23d569855235460184a267a5744c71f5d398',
#   891: '92d81e059c410ad9fccc09512da82ce7b5f3729d9fc3473f03249b478ba6f5d4',
#   892: '0b867b0a9aa1ad65c169ca126c6634865f97f56a160779b814083042fba3a88a',
#   893: '234d0e291eeb148bafc71af688b703f91b4365ed6fad35bf43b1468ad80a2d49',
#   894: '85c05792034b49a29fff62326140e7e00b5b6541c8acb090144dd40f033f156e',
#   895: '161300f88cff18b6517308d86c0bf48057258f1987b5f26705d0ee95225998d7',
#   896: 'f5c55abad4d8e9bf6bffdbf96296d9d5170ed5e72b186a82ee93dfc5e55a7e00',
#   897: 'c876c6f5c86dee0a2ef45684e72056478862cecad1255a306c407bac0bfb6d03',
#   898: '9360263e5694d321256bd3ea7cb4c33e79f5f2f2c4d716114e8217dbcb9b6d26',
#   899: '425d5266d03267ab34f1e77cc1ccda7e4201493a40ae7ea139928255b2724a48',
#   900: '3e10ea526fed24c583eb151706f47de12c645c87127b448c0efcd643e34ce433',
#   901: 'd96009aadd15365fef0b4272566cd60fe621ccfda6095d2c3029d02d3fbd8e88',
#   902: '7a657d48b14369bb86e49f94872f8bb45f3b2d8b4e98fe7ced1f7bca43b171b6',
#   903: '82b68cd742638edf2e53734d0e81bc5da62d139ffb36aebe028e6f8f51ca7625',
#   904: '3e773a3d555f1e2a3ed395a99aa966521065c260297ee3d929b1f60d682e8489',
#   905: 'a30718c0f25d91defb8e22f274c53f724e9477160c3a3088dac785d020e09dc4',
#   906: '321f40ccda2010ec4086320f6906806772ddc029195b05ba1eb45eef5898c3fd',
#   907: '605370a2217fbbc175a93867ca5ea2221d63d93f91bfc9c33e9cd8c05e19bd35',
#   908: 'b56f5e718de45bf128cc4cb27a78eca112e0bc2e8361e82f70964f37a80d99e7',
#   909: '162e29efa9542557c2847a7bc05254807ef0143899827c303fcbac0368e963ef',
#   910: 'afc08e31a48ed7e94e42fb0bd363537b2cd99c5e8c1ea1ac84142ba21389d1e7',
#   911: '8b0756be0f43f08eeae8b040575eefd3a9c4d298c0bae2c69f3fbd0308912748',
#   912: '0fe5dc5d5f303f54c0f140efea1a66b9529f9e237a58105c9554f2f8ce29897b',
#   913: '4ac04888a6d96f886573c8af8d3c94309fc580dada4b0b7b4217bd3c10170b81',
#   914: '3bf42d3e87e7305eceea0ccc5fc183fdef074848e62b81ed17dee97edcd92a06',
#   915: 'd2d10737fcb2e752ce2ab4faa47e0752b25cb171f63e234d8154fd4ae623e952',
#   916: '2d0bc042d8f79b6103ece7dfd3c842c67552f712b570e7a03fd63262714ec535',
#   917: 'b6f22e9847e5032b087b88a6116ebc8c1c142d76e3633f0390843f2744f6eade',
#   918: 'df97989425645395fb675c7f3b8aa4b609e8a06bc28bf4ae7e5f314abc09cbcb',
#   919: 'f3f52c9b2b4966972b3692e12410ee3df6c6f1a33d5d3753cac42dfbd5baf37f',
#   920: 'e7156e9810f0f8fd79df37e11980da5a8cc2b7adf307c97ccc75afbee5f1dc6d',
#   921: '286163b0ac565a867b1fac4d5624e19603d2e785c767cbed25de423c5578c84a',
#   922: '0a484ce8a39bb2e2d9174c8eacc378b3373cb6f4af568b14a8b8e110dcddb9b1',
#   923: 'e7c2da7b4a05ae6869d2cc5105817bcc8b5121fab050f0666e9909c7edac2ec2',
#   924: '92c2321b9ca0c6eb19859bcdac4f997475f897b8b1066ace8c381c12f04fa0d0',
#   925: '45bd62ef2cb1c0c8f73ee183560b3231b0016f7187da718ba50e142e43ca5fcb',
#   926: 'efdcd98a1aefdc93064b219f9230ee955ed70658dd9f5258b4dcd3593509f184',
#   927: 'f2406c5216d464b45007866cfed313243fea138800e2c2fce281ef4078b99bf1',
#   928: '75d1ae7bfb936f0cf06a7e5fb84aa0af04f5544d181d5cee8c83cb7f7d3c2fce',
#   929: '5137f422531e58866c423b259a59f5cef2009d36828efb832616dfce1b4960c7',
#   930: '049665ed02cacc2c0412a2e63c685c94d9ba2fd55e1071faee7e253a1c864825',
#   931: '3829a31dec0e166b079296ad003c1d6f9ba866cd9a2fb3baded7743601249d01',
#   932: '7bd76dbef361ea309f45d23330f5ac89e213b33072d7e2f9f379dee68c3d3898',
#   933: '4f2fec6e29ca15eaab748e4afbc3ddc8ee991d7bf60721a7f7396064ccc34911',
#   934: 'e78bb78000c7e6ba95edb26e5d254f28227fea754f316cae18e376888f613029',
#   935: '2544bd98beddd693b070ae336a50ce8ceac27f24a021ed6d53dcc27cf9aaeb38',
#   936: '20a06157d71b987f7c146891b88ed1ade45f0beb24e97eeaef0eca1bdcfe53a2',
#   937: '7f82aac10ef3fa1ecf401bfaf124e8f998cfa2ba06c1772041e56d00e4d9c398',
#   938: '69d7a991fb4e4ce5eadac87ee07932d29742ec2225ea401d441aead8555ec8cc',
#   939: '338db67f8c60690b8cb68e81804c2e68c8e887455bfeceb810b70eeee430325e',
#   940: '63f67609841963ccd420073b1c4cc241803fad19f0b4a372f8942f2f3f070779',
#   941: '04c473953ae5461c8d55240b5b503e0cd41bf1ed240c5bfed608005b46694acb',
#   942: 'e9f75f24bec214b9f0c38d33d7d9cbfe958dce6c27c820be0581989c5b39e829',
#   943: 'acd5939da1672aa186adb11b5a8bcfe4a8a7e2be2d2bad000bcc5af7e03f0ee3',
#   944: '1714812428b5055464f868d5e739835c032c9ff6e4a25c5dbb179098f5133768',
#   945: 'ae4222add9c526ab1cd222e0f0efa1d87fad31e95af0d736cd34f0a00a512ab3',
#   946: '4587b0aa4dd045aa94f2f529d41c7b308c399eb6b4d8c0ace1f1d2ad6784a720',
#   947: 'fb751bf5def3bcbbd984761a79584f9b2c187cee27f5286897a4c3f24345e120',
#   948: '1e9928f6421dcc6c420e4e8a73647c570cc73a319376ce534a5bd5b47cd8e2e0',
#   949: '9cf10c1848aaf5bfbaa6c3c9e83ae93057ebe8f9477a968b572e98fd2c3cdc45',
#   950: 'd618f53fa8f8aa678d4e25a32283c0fdadef42f13540ad7f7406cbdaf79581f9',
#   951: 'cf91ceb331515854d23d018fc1a7393609d987c793fd044b1af2e72268868d39',
#   952: '73749d3ff13fb7ed030cfaeb85a64b966b61d36f728cfd83b4fde9316f4f11cd',
#   953: '1cd7bd6f39010ec0f82b344b05860a3bc2eb56e34f4d953c48a90c136122bc83',
#   954: 'd56471d8fea2faec77a7e5e8af513eb0a1abc8e7fe2e371106d001db45b04ae6',
#   955: 'f1b844739232557000c98eec1c2fcbb0c226ca76eb90d87121dc36a74f10761b',
#   956: '72c82e81d16a33318ad4d97f88cdd0fc12b9896178016d154a2a64255f7ac3e4',
#   957: '960d90ca32aae649a7e9357c1ed4ff891c4bd562169decb4068030eb30c85406',
#   958: 'bb4b158a595f25db38363babdd5d76ccb9921bd3eda0e058996a64249890c60c',
#   959: '2381847741fc40e454da4bf2066fa8f9867e689c53961d3ec45d01a0f1added2',
#   960: '4f72fe0a4af5354cebbdd1f1f4e30b141ff673b7e1aedcf30ca3cfd8dce7bb0f',
#   961: 'c915025295d5f92bd53608d4883468b9525845139715e4adc977af731ba82896',
#   962: 'cbb2f69eae0b864910b5405e46329c82863c9727750a7245cec3334235e3d62e',
#   963: '6a83a894a1488bba0bbe3d211edb6b1e40762b947285aa6c4fc7dd88b659541b',
#   964: 'cccf7f8b704d4480774f6b29ce2013324854e85ee1452c77db39926b8a2758a5',
#   965: '07273de3ab38e584bf9c14f5fe61b40e516b2df63f32e6d34883c31859f0c57b',
#   966: '2eafd9e896520d8b02b5e70a2596a1e5da638950a5a17587a76c6134a90a1848',
#   967: '1f96037816bb01cad6e97d5ce7be871db379d3b7f881f3f168c61d1484ad5964',
#   968: '48c39c4ce021761185aa352db60363c1109684c3243b89e170eab2306787ae45',
#   969: '6c0be69f1b3f6fb59d35c04aad89ed44de8d9df6975b8bde4d36e24794fe5b11',
#   970: 'a988859d46615e991842fdd47d4f9b93bb38326d2424be8729ab29a5da4e9e46',
#   971: '12f6b93f684d3e4399077d066eef111d7581d62bbaa0c275654b9ad7ac9f2385',
#   972: 'd9f67c535900bd01e439cffe2b1ea4a6ba8a40201c821647fe48c43805992154',
#   973: '54c34537c535b0d65de7a47fcd32e10f2b40535311f69a0d541ab800386609e6',
#   974: '56e5f95172d292f7b9d22e64176a79cc5a4dfdd5e2442bfad72b08d606396601',
#   975: '77096b5942cc91afc946803deba2fa85314fb4343178eb6fe6712f6905b3e6b9',
#   976: 'b89b5e1fea12a0ab78c29ca87649bf2687f1558dd0e67c93036996e81d7438c5',
#   977: 'aac3618d5a898040177140716adbab02c4389448a0d351d0762fd027e719c2dc',
#   978: '3311663049fc19e9f878bd6e05ed36e8efcb8f58b802be7ae5cdb6db5ceccb81',
#   979: '9509a3a1480fd63999e2a3a5318d8103f172432733b3c0a48347d038f4e896e3',
#   980: 'a0dd3f78692a0c106558b52322181d3f48fe94b057f90163e491606b70d16fde',
#   981: 'cac8521d4059ccece3286dea1537e8965c0caed080555f56c682204932edcc61',
#   982: '8e983825b5269d970eae7965d002212474de576f3d0be1b2696aee7a17589e96',
#   983: '1b7c9418cdb554d52a8b7a47f6c136e0babfde8414f14edf2f6195d188323820',
#   984: '603e3441013d857dfa91bb40666c86778307cd638509095978be794292a0bf18',
#   985: '138eadc58b082d729aaa363c51ccbe2a05e92ce0bdd4370ae2d0d3ea893a3cfb',
#   986: 'a0e69621109f2026b20aea5a14751222311bc5f7a900eb254ccb057dd0a01cf7',
#   987: '4e7e029ac6253f8ae910aca480ffeda0b545be7bcb0fe19083b1458d8c0794a6',
#   988: '178a4c661ab8b341fefa3129b68605a64f484ae4baec28c6fc10753befe8542f',
#   989: '220174206bf55fbd6775b63a30a5b2ad01d5faadd2c55deef71642808db19716',
#   990: '031e765d2638c334cd551582e2f3804e9ec150440e55af180dd2eb3dbbca75f4',
#   991: 'e0127bd2dc3d78c0c8c1efcc3b57c7c91c93400113d02bb11e0e049abc35913e',
#   992: '985f7e30cbecbea5e516ac816760509350e133f13f85698d5ca4d935a8e85f32',
#   993: '0e846cce728ec456daac5183734ba0142a8fb55c06c0eeff3f9d996fb078df93',
#   994: '37f7f448392feeff10ff9a7f5c1ae978c644b48b97567c7394db91ac086603a0',
#   995: 'a9395850a1a2b54a74dd297502cd1014c43e113102db1cb284beb32deb859daa',
#   996: '7f8c8e021d7e14af5239925aac56c32e529d45b833baacf8b5a064d2ac2826ba',
#   997: '0e0646b76d0245ca30c2db5fe5d9213344a20b895fe1986d5243206219fe852e',
#   998: 'bc83005f4040b1c275cd7e7cad4ebd538802e2e0c0b0c676641e435e06b2f800',
#   999: '762e9331dec0693f476fdb01ffc573ed12994df6091a7cb37cfa87c2ac3fcc8a',
#   ...}]

# %%
replaced_cols = ['chid','cano','mchno','acqic']
df[replaced_cols]= str_trans_num(df,replaced_cols)
df.head(10)
# Out:
#                                                txkey  locdt   loctm  chid  \
# 0  a2c1209018e4e52e04f6fabb48f05f1b8bc09dc838ff6c...     56  105157     0
# 1  16c4880500059e01553789be11bbb50753b7acaae7b95b...     56  185520     1
# 2  623c56be3bee87724e3d119c271d9ed098eeda84233183...     59  102312     2
# 3  250da12187059cf6e3a3066656a2919d08ceb8207efd55...     58  230138     3
# 4  4b268e0da036f44cbbb056ddfac6a28ea336d9cf299843...     59  101937     4
# 5  fd64ce519d3850ba9da4ee7fd0832222693193088e89dc...     59  152823     5
# 6  0c93f45dac9454a159daacfd6bb1f63fabd6c75d92a47e...     59  113224     6
# 7  f46b16150256c36df77817ccc9a8450e82532457dcb1ad...     56  131739     7
# 8  b62dc04dd4442d27e6a6c87ab82ad98b11f04737d54f97...     56   83744     8
# 9  6f230b30cb79f7b5791348b2a0464cbc92682d94bdd8e9...     56  163138     9
#
#    cano  contp  etymd  mchno  acqic    mcc    conam  ecfg  insfg  iterm  \
# 0     0      4    1.0      0      0  272.0  1353.00     0      1    3.0
# 1     1      5    8.0      1      1  320.0   305.00     1      0    0.0
# 2     2      5    1.0      2      2  494.0    20.00     0      0    0.0
# 3     3      5    5.0      3      3  272.0  8371.00     1      0    0.0
# 4     4      5    5.0      4      4  217.0   163.69     1      0    0.0
# 5     5      5    5.0      5      5  275.0    10.00     1      0    0.0
# 6     6      5    4.0      6      6  282.0   125.00     0      0    0.0
# 7     7      5    8.0      7      7  320.0    55.00     1      0    0.0
# 8     8      5    5.0      8      8  276.0   222.00     1      0    0.0
# 9     9      5    4.0      9      5  298.0  3090.00     0      0    0.0
#
#    bnsfg  flam1  stocn    scity  stscd  ovrlt  flbmk  hcefg  csmcu  csmam  \
# 0      0   1349    0.0  15759.0   -1.0      0      0    6.0   70.0   1349
# 1      0    306    0.0  13451.0   -1.0      0      0    6.0   70.0    306
# 2      0     20    0.0  15759.0   -1.0      0      0   -1.0   -1.0      0
# 3      0   8339   42.0  12381.0   -1.0      0      0    6.0   70.0   8339
# 4      0    163  126.0  14786.0   -1.0      0      0    6.0   68.0      5
# 5      0     10    0.0  16115.0   -1.0      0      0    6.0   70.0     10
# 6      0    125    0.0  15759.0   -1.0      0      0    0.0   70.0    125
# 7      0     55    0.0  15759.0   -1.0      0      0    6.0   70.0     55
# 8      0    222    0.0  15759.0   -1.0      0      0    6.0   70.0    222
# 9      0   3100    0.0  15759.0   -1.0      0      0    6.0   70.0   3100
#
#    flg_3dsmk  label  weekday  h_loctm  m_loctm  s_loctm   mins_loctm  cano_num
# 0          0   -1.0        0       10       51       57   651.950000         0
# 1          0   -1.0        0       18       55       20  1135.333333         1
# 2          0   -1.0        3       10       23       12   623.200000         2
# 3          0   -1.0        2       23        1       38  1381.633333         3
# 4          0   -1.0        3       10       19       37   619.616667         4
# 5          0   -1.0        3       15       28       23   928.383333         5
# 6          0   -1.0        3       11       32       24   692.400000         6
# 7          0   -1.0        0       13       17       39   797.650000         7
# 8          0   -1.0        0        8       37       44   517.733333         8
# 9          0   -1.0        0       16       31       38   991.633333         9

# %% [markdown]
# 連續盜刷的人之中，近八成(79.7896%)在三天內遭連續盜刷，66.43%在同一天內連續盜刷

# %%
AA = df[(df.label!=-1)].groupby('cano')['label'].sum()
AAA = df[df.cano.isin(AA[AA>1].index)&(df.label==1)]
AAAA = AAA.groupby('cano')['locdt'].transform(lambda y:y-y.min())
(AAAA.value_counts()/len(AAAA)).sort_index().cumsum().plot(kind='line')

plt.title('Cumulative Percentage of fraud_consecutive')
plt.xlabel('Categories')
plt.ylabel('Cumulative Percentage')

# 設定 y 軸範圍
plt.ylim(0, 1)

plt.show()

# %% [markdown]
# 正常跟異常資料的個數跟比例

# %%
print((train['label']==0).sum(),(train['label']==1).sum())
# Out:
# 8656497 32029

# %%
print('percent:{:.2%}'.format(32029/8656497))
# Out:
# percent:0.37%

# %% [markdown]
# ## 缺失值檢查與填補

# %%
train.isna().sum()[train.isna().sum()>0]
# Out:
# etymd     203455
# mcc         4550
# stocn        600
# scity     266066
# stscd    8665195
# hcefg     286656
# csmcu     498657
# dtype: int64

# %%
train = train.fillna(-1)

# %%
# train.stscd = train.stscd.fillna(-1) #8665195
# train.mcc = train.mcc.fillna(-1) #600
# train.stocn = train.stocn.fillna(-1) #600

# %%
A = train.isna().sum()
A[A>0]
# Out:
# etymd    203455
# scity    266066
# hcefg    286656
# csmcu    498657
# dtype: int64

# %% [markdown]
# acqic在搞

# %%
train[train.acqic=='4d349d9cd02873b7cc8519caea9b55bc716417aeb0547cfb16d9b9e20be23b91']
# Out:
#                                                      txkey  locdt   loctm  \
# 6075042  c2fdf5bf7535734f8413aa9fcd87db9ffae360cbf036aa...      7   82028
# 8209901  f174e0c82bcbeb63157cdb31b2dc5879db7f942f8c625f...     20  123229
#
#                                                       chid  \
# 6075042  d1e4a9a90d1a67f60c6212a9651f76a4f25e534e13df13...
# 8209901  ddf228808e1bf4588e4d450e226f5c424c212fb1786697...
#
#                                                       cano  contp  etymd  \
# 6075042  04b400656e4ec85dc3369fe7448f41de238e2e938a0f1b...      5    NaN
# 8209901  8c5086904f5150a6c71d505d7f34c5ba61948bbe7d9638...      5    NaN
#
#                                                      mchno  \
# 6075042  4b184bc24ca32587f2468cfb1376a2f787512447dd1ab5...
# 8209901  4b184bc24ca32587f2468cfb1376a2f787512447dd1ab5...
#
#                                                      acqic    mcc  conam  \
# 6075042  4d349d9cd02873b7cc8519caea9b55bc716417aeb0547c...  495.0  500.0
# 8209901  4d349d9cd02873b7cc8519caea9b55bc716417aeb0547c...  495.0  500.0
#
#          ecfg  insfg  iterm  bnsfg  flam1  stocn  scity  stscd  ovrlt  flbmk  \
# 6075042     0      0    0.0      0    502    0.0    NaN    NaN      0      0
# 8209901     0      0    0.0      0    499    0.0    NaN    NaN      0      0
#
#          hcefg  csmcu  csmam  flg_3dsmk  label
# 6075042    6.0    NaN    502          0      0
# 8209901    6.0    NaN    499          0      0

# %%
# train[(train.stocn==0)&(train.scity.isna())].mchno.value_counts()
#train[~train.mchno.isna()].mchno.value_counts()

train[train.mchno.isin(train[train.scity.isna()].mchno.value_counts().index)].scity
# Out:
# 49             NaN
# 64             NaN
# 71             NaN
# 76             NaN
# 78             NaN
#             ...
# 8688415    15759.0
# 8688432    15759.0
# 8688484        NaN
# 8688486    15759.0
# 8688509        NaN
# Name: scity, Length: 529902, dtype: float64

# %%
train[(train.stocn==0)&(train.scity.isna())].acqic.value_counts()
#len(train[train.acqic=='814437ad6838efec5e9ebd8600d37a984f221ca2f7a83fb66ccd80505e585745'])

#train[train.acqic=='814437ad6838efec5e9ebd8600d37a984f221ca2f7a83fb66ccd80505e585745'].isna().sum()
# Out:
# acqic
# 814437ad6838efec5e9ebd8600d37a984f221ca2f7a83fb66ccd80505e585745    114349
# 8ccfdd7858e90e854599488e0f7453996a6268788bf36983ec81e10bc147f826     44449
# 16e2a0ad7a09b6a46a5711b9f79965689383832e4e02dc270da0e35810306270      9056
# cf12b86a163b0dc6b9d671540aa04b0f533248c91add689f3560c9cc634273fb      7991
# 760a1509f55f2f9f43f8253c2519fa64bd3b3a10f045b393499a454916369501      6506
#                                                                      ...
# dfb3e02d7c907422a4e502b604e32e4f044dee206ffb8202aaa11726276ab8a7         1
# 367f6aa227bb5a3051f45cc3c143d1a4e231516292a8242bb0ab1ff454aa704f         1
# 9452bfd9c39f730e9941ad0498ef952a10bd260ce3084e7c01ac1f221ebd2ebc         1
# 474f5ca19dde0bcf7f4d718f12b5bda6cd450744116dc08e8c4a89d0ad645bea         1
# d0596273fe357a0af39fc6beaefd9cb1317b40ca24e54355ff7a35dd318e92fa         1
# Name: count, Length: 5881, dtype: int64

# %%
train[train.stocn==0].csmcu.value_counts()
# Out:
# csmcu
# 70.0    7349441
# 68.0      15733
# 81.0          1
# Name: count, dtype: int64

# %%
train[(train.csmcu==68)].stocn.isna().sum()
# Out:
# 160

# %%
train[(train.stocn==0)&(train.csmcu.isna())]
# Out:
#                                                      txkey  locdt   loctm  \
# 49       16679b5ed32d59fa97953f8fdc286959aef492c8a6595f...     28  174101
# 64       8ad26d8a1ef96ed9ad70c2d9c3ec023381f498b56539fe...      7  154904
# 71       0f722184ac164224078b5ccbe5196d528651734de76d99...     21  105508
# 76       5e58377aaa4c56394727f1ab11761c55a9740fe7c9a560...      3  143109
# 78       b3322bd18354880198968eaa1e7ff7b4df7bbe92fbe1e1...     19  164910
# ...                                                    ...    ...     ...
# 8688415  4ce931d97e9a1808b993033dcfa0eaa390b7b88639935a...      0   83659
# 8688432  80d29b6739a4de25492bb8a0c1709768dd3e423c4cc6dc...     14  102919
# 8688484  2a820b46eae154c569f473e47745a39f4dfda15aace940...     16  143106
# 8688486  de101459f39f9bf3073e2f1d6d8ed18cf82bad16fe0862...     14  101836
# 8688509  71daa1e80c664bcdbf7128944fd467ba8007e44eb1e7f1...     21  192551
#
#                                                       chid  \
# 49       54a108762edf70d98b5039cfcb164e43ce6e2591d06338...
# 64       d1c0edf7f0db8706d33a83304ac95a67d230ef05994d7b...
# 71       70c093f32abca8aba41e3bc34e95399ba3df425ae44d09...
# 76       1dfd565c8559c67975e37eb6809d306e4104f6c0a51819...
# 78       8da02baf0edd588464de1c8ee304564a0b0e8fed4d9a01...
# ...                                                    ...
# 8688415  ee4d9637b817b74a092d795f72d42bdde6b3f1b66316cf...
# 8688432  1bd4751bd62b6d5c5ad056e7c653ce14f81bd35027a24f...
# 8688484  f0b481311a81fba645a005599c764cabeacd21a10ac417...
# 8688486  5fb5c9769732acc1a614b6d2d8ba7fef602d9570996d4d...
# 8688509  792106462a71852e2487d36ec6c629ed8197b437d3d835...
#
#                                                       cano  contp  etymd  \
# 49       2e0c76da02b728454f46ca145be3bb653875d8f3a5afa8...      5    NaN
# 64       87398a171b24efa432b5e2106a86b60e6d442e1e36bd08...      5    NaN
# 71       81b8a68577be5ef936eaf91eb9d324113672a8c92f306b...      5    NaN
# 76       1d9556ee39c334dfe88dfdd72da82d23e68a5549118f3a...      5    NaN
# 78       78b20f5ebec33ec09889a954c93f877aa67ac266daf69b...      5    NaN
# ...                                                    ...    ...    ...
# 8688415  b2ad42da4ea14e90784ddb5b173dd4ee25b60ae3c89a73...      5    1.0
# 8688432  5aaf943cc44f5d9371542a572654d5e03ad4e1999833a8...      5    1.0
# 8688484  70dfc1fbf29fd5a556f9ac39e5455832106d539422b4bb...      5    NaN
# 8688486  21840da738267c8686f50b399a294529cf257da4ded950...      5    1.0
# 8688509  318cc11bc84b3807c0d4fe993d21321a0559574a6b881d...      5    NaN
#
#                                                      mchno  \
# 49       20ed456deae86bf216176c4e488ba5ce174e197208209e...
# 64       f1a36c672aaf32222b8c8ed023c6a8edfe5f8e52a781d7...
# 71       0bd7da8c4387afa9a1d96367ed0436ab28fb07b0bb9a84...
# 76       0bd7da8c4387afa9a1d96367ed0436ab28fb07b0bb9a84...
# 78       0bd7da8c4387afa9a1d96367ed0436ab28fb07b0bb9a84...
# ...                                                    ...
# 8688415  9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6...
# 8688432  9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6...
# 8688484  6b0f2ca4ce5589561bcc92866f9e118dc03ffc82f63769...
# 8688486  9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6...
# 8688509  ea2f2f9e85b8782f8493dfeef7dd3cfa6f9d107e70b987...
#
#                                                      acqic    mcc  conam  \
# 49       814437ad6838efec5e9ebd8600d37a984f221ca2f7a83f...  499.0  500.0
# 64       814437ad6838efec5e9ebd8600d37a984f221ca2f7a83f...  499.0  500.0
# 71       814437ad6838efec5e9ebd8600d37a984f221ca2f7a83f...  499.0  500.0
# 76       814437ad6838efec5e9ebd8600d37a984f221ca2f7a83f...  499.0  500.0
# 78       814437ad6838efec5e9ebd8600d37a984f221ca2f7a83f...  499.0  500.0
# ...                                                    ...    ...    ...
# 8688415  9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6...  493.0  400.0
# 8688432  9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6...  494.0   20.0
# 8688484  8ccfdd7858e90e854599488e0f7453996a6268788bf369...  499.0  500.0
# 8688486  9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6...  494.0   60.0
# 8688509  8ccfdd7858e90e854599488e0f7453996a6268788bf369...  499.0  500.0
#
#          ecfg  insfg  iterm  bnsfg  flam1  stocn    scity  stscd  ovrlt  \
# 49          0      0    0.0      0    500    0.0      NaN    NaN      0
# 64          0      0    0.0      0    498    0.0      NaN    NaN      0
# 71          0      0    0.0      0    502    0.0      NaN    NaN      0
# 76          0      0    0.0      0    499    0.0      NaN    NaN      0
# 78          0      0    0.0      0    500    0.0      NaN    NaN      0
# ...       ...    ...    ...    ...    ...    ...      ...    ...    ...
# 8688415     0      0    0.0      0    399    0.0  15759.0    NaN      0
# 8688432     0      0    0.0      0     20    0.0  15759.0    NaN      0
# 8688484     0      0    0.0      0    501    0.0      NaN    NaN      0
# 8688486     0      0    0.0      0     60    0.0  15759.0    NaN      0
# 8688509     0      0    0.0      0    501    0.0      NaN    NaN      0
#
#          flbmk  hcefg  csmcu  csmam  flg_3dsmk  label
# 49           0    6.0    NaN  49955          0      0
# 64           0    6.0    NaN  49765          0      0
# 71           0    6.0    NaN  50200          0      0
# 76           0    6.0    NaN  49905          0      0
# 78           0    6.0    NaN  50050          0      0
# ...        ...    ...    ...    ...        ...    ...
# 8688415      0    NaN    NaN      0          0      0
# 8688432      0    NaN    NaN      0          0      0
# 8688484      0    6.0    NaN  50070          0      0
# 8688486      0    NaN    NaN      0          0      0
# 8688509      0    6.0    NaN  50145          0      0
#
# [462815 rows x 26 columns]

# %%
train.csmcu.value_counts()
# Out:
# csmcu
# 70.0    7947443
# 68.0     122569
# 81.0      27575
# 29.0      27074
# 76.0      12450
#          ...
# 80.0          2
# 5.0           1
# 21.0          1
# 83.0          1
# 4.0           1
# Name: count, Length: 79, dtype: int64

# %%
train[train.cano=='e7f56d2d90f07715c5fc8d62634ea35f00779297b72fe41668f5e734172db273']
# Out:
#                                                      txkey  locdt  loctm  \
# 21205    f94753408bc6ddc079b395c38256db19c5d1bb8bb6f692...     26  75652
# 853441   2162163ecedd706a55e601fb718a95a86e2b219e246e12...     28  63144
# 5199370  8dec519fddc54767f0ea2c722abab00c7dbd937ca3e38c...     25  51223
# 5467611  20d4ad186461b724b82a312bcc9c5507800f2440d8a375...     28  62632
# 6974601  56bf1f835d23c437fbb3c178411f82ef7251c0fdd71bb6...     28  62631
# 7201705  d2cb1b58a3f81fa607bd98eed3350ff247f1181d8cc065...     28  63143
# 8027340  632253e79156ab803b399f4a0a3f3bccd9950025cf748e...     26  75651
# 8361497  6d5b601f364a2ce7a52c76bc26f20bc4acf27196e36c6b...     25  51224
#
#                                                       chid  \
# 21205    9adf180bf1491b4cba3a021201076b04e8fc51e802365b...
# 853441   9adf180bf1491b4cba3a021201076b04e8fc51e802365b...
# 5199370  9adf180bf1491b4cba3a021201076b04e8fc51e802365b...
# 5467611  9adf180bf1491b4cba3a021201076b04e8fc51e802365b...
# 6974601  9adf180bf1491b4cba3a021201076b04e8fc51e802365b...
# 7201705  9adf180bf1491b4cba3a021201076b04e8fc51e802365b...
# 8027340  9adf180bf1491b4cba3a021201076b04e8fc51e802365b...
# 8361497  9adf180bf1491b4cba3a021201076b04e8fc51e802365b...
#
#                                                       cano  contp  etymd  \
# 21205    e7f56d2d90f07715c5fc8d62634ea35f00779297b72fe4...      5    1.0
# 853441   e7f56d2d90f07715c5fc8d62634ea35f00779297b72fe4...      5    1.0
# 5199370  e7f56d2d90f07715c5fc8d62634ea35f00779297b72fe4...      5    1.0
# 5467611  e7f56d2d90f07715c5fc8d62634ea35f00779297b72fe4...      5    1.0
# 6974601  e7f56d2d90f07715c5fc8d62634ea35f00779297b72fe4...      5    1.0
# 7201705  e7f56d2d90f07715c5fc8d62634ea35f00779297b72fe4...      5    1.0
# 8027340  e7f56d2d90f07715c5fc8d62634ea35f00779297b72fe4...      5    1.0
# 8361497  e7f56d2d90f07715c5fc8d62634ea35f00779297b72fe4...      5    1.0
#
#                                                      mchno  \
# 21205    907e2b1e5adf39ca1f65b6e8251c41f74537ebdb3118e2...
# 853441   907e2b1e5adf39ca1f65b6e8251c41f74537ebdb3118e2...
# 5199370  907e2b1e5adf39ca1f65b6e8251c41f74537ebdb3118e2...
# 5467611  907e2b1e5adf39ca1f65b6e8251c41f74537ebdb3118e2...
# 6974601  907e2b1e5adf39ca1f65b6e8251c41f74537ebdb3118e2...
# 7201705  907e2b1e5adf39ca1f65b6e8251c41f74537ebdb3118e2...
# 8027340  907e2b1e5adf39ca1f65b6e8251c41f74537ebdb3118e2...
# 8361497  907e2b1e5adf39ca1f65b6e8251c41f74537ebdb3118e2...
#
#                                                      acqic    mcc     conam  \
# 21205    ea8724e1181e9a7318604aa768bb5cfbfca5b85c75b1b7...  486.0   4270.09
# 853441   ea8724e1181e9a7318604aa768bb5cfbfca5b85c75b1b7...  486.0   5539.58
# 5199370  ea8724e1181e9a7318604aa768bb5cfbfca5b85c75b1b7...  486.0      2.32
# 5467611  ea8724e1181e9a7318604aa768bb5cfbfca5b85c75b1b7...  486.0   8540.18
# 6974601  ea8724e1181e9a7318604aa768bb5cfbfca5b85c75b1b7...  486.0      2.31
# 7201705  ea8724e1181e9a7318604aa768bb5cfbfca5b85c75b1b7...  486.0      2.31
# 8027340  ea8724e1181e9a7318604aa768bb5cfbfca5b85c75b1b7...  486.0      2.31
# 8361497  ea8724e1181e9a7318604aa768bb5cfbfca5b85c75b1b7...  486.0  11131.75
#
#          ecfg  insfg  iterm  bnsfg  flam1  stocn  scity  stscd  ovrlt  flbmk  \
# 21205       0      0    0.0      0   4291    NaN    NaN    NaN      0      0
# 853441      0      0    0.0      0   5566    NaN    NaN    NaN      0      0
# 5199370     0      0    0.0      0      2    NaN    NaN    NaN      0      0
# 5467611     0      0    0.0      0   8581    NaN    NaN    NaN      0      0
# 6974601     0      0    0.0      0      2    NaN    NaN    NaN      0      0
# 7201705     0      0    0.0      0      2    NaN    NaN    NaN      0      0
# 8027340     0      0    0.0      0      2    NaN    NaN    NaN      0      0
# 8361497     0      0    0.0      0  11185    NaN    NaN    NaN      0      0
#
#          hcefg  csmcu  csmam  flg_3dsmk  label
# 21205      6.0   70.0   4291          0      1
# 853441     6.0   70.0   5566          0      1
# 5199370    6.0   70.0      2          0      1
# 5467611    6.0   70.0   8581          0      1
# 6974601    6.0   70.0      2          0      1
# 7201705    6.0   70.0      2          0      1
# 8027340    6.0   70.0      2          0      1
# 8361497    6.0   70.0  11185          0      1

# %%
#train[train.stocn.isna()].cano.value_counts()

train[train.stocn.isna()].cano.value_counts()

for index, value in train[train.stocn.isna()].cano.value_counts().items():
    if len(train[train.cano==index])>1:
        print(index,len(train[train.cano==index]),'比例 ={:.2%} '.format(value/len(train[train.cano==index])))
    #print(value/len(train[train.cano==index]))
#        print(f'cano: {index}, count: {value}')
# Out:
# 2ec598d135c3718aa180a727f089c490270e9d30f4f34f9adc8f4ebdd88db817 330 比例 =9.09%
# 1e76714d2928e0dc1b76060f28bd8c52a351a206194b076625a521c70289bc6d 43 比例 =20.93%
# 7340e3a3204f1928a6d68c6d9dcbbb82daad446e8fe2911097043c60a57aa65b 225 比例 =4.00%
# e7f56d2d90f07715c5fc8d62634ea35f00779297b72fe41668f5e734172db273 8 比例 =100.00%
# ce453e0b14800885ffa456680d83c9aea3a69d52aa4cec133906ec26bd5ec405 97 比例 =8.25%
# 67da333485d94ed55487640cf33edaa6167131f5f37d029730c7c8830e1affb2 128 比例 =5.47%
# 3f6519d1512e16ac9631b6b4912e16a138fbe2656dd6e76bdd6442c276908b05 166 比例 =3.61%
# 585ac946c62458b035cd00bb18939159c52c1ffb393227a3fc863955d7274503 34 比例 =17.65%
# 02012023ee36c30f9223e918acf4c8fa85cdc8b4ae5f3cc2ed781d7a11470748 212 比例 =2.36%
# 3103e5e0639f9afd6b999153be6a54df116ec52006d6db75c536b645381481b6 24 比例 =20.83%
# a75f21acb09fa26bc24679c0950ab01d7c1f97c9951e2778e386562ef6e25966 121 比例 =4.13%
# 733b8c7dc2335ded7ad26e62f38c2a54fe931c2186920e1cb7f69a9f04cf2abb 208 比例 =2.40%
# 2e21b3b974cbd2437f92061ac3b4c104b8c717a180426c9be3997560107ede50 10 比例 =50.00%
# 61bce92b8435edc5f7c75e7ebfc3eb6ead147050b59e6faf2743e7ebcb61bc48 64 比例 =7.81%
# 296c07cef2f24c5417dca2782d698e953a56c5a47cc8a2f21d423ad2c9866ae9 202 比例 =2.48%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\cool8\Desktop\AI_CUP competition\feature_engineering.ipynb 儲存格 13 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y163sZmlsZQ%3D%3D?line=4'>5</a> for index, value in train[train.stocn.isna()].cano.value_counts().items():
#       <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y163sZmlsZQ%3D%3D?line=5'>6</a>     if len(train[train.cano==index])>1:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y163sZmlsZQ%3D%3D?line=6'>7</a>         print(index,len(train[train.cano==index]),'比例 ={:.2%} '.format(value/len(train[train.cano==index])))
#       <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y163sZmlsZQ%3D%3D?line=7'>8</a>     #print(value/len(train[train.cano==index]))
#       <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y163sZmlsZQ%3D%3D?line=8'>9</a> #        print(f'cano: {index}, count: {value}')
#
# File c:\Users\cool8\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\cool8\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\cool8\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:5799, in Series._cmp_method(self, other, op)
#    5796 lvalues = self._values
#    5797 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5799 res_values = ops.comparison_op(lvalues, rvalues, op)
#    5801 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\cool8\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:346, in comparison_op(left, right, op)
#     343     return invalid_comparison(lvalues, rvalues, op)
#     345 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 346     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     348 else:
#     349     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\cool8\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:132, in comp_method_OBJECT_ARRAY(op, x, y)
#     130 else:
#     131     result = libops.scalar_compare(x.ravel(), y, op)
# --> 132 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %% [markdown]
# etymd 在盜刷的時候缺失值是正常交易的1/10

# %%
print(203455/len(train))
print('理論上，etymd在盜刷情況下缺失值有',round(203455/len(train)*sum(train.label==1),2),'筆，實際上僅',sum(train[train.label==1].etymd.isna()),'筆')
# Out:
# 0.02341651506826359
# 理論上，etymd在盜刷情況下缺失值有 750.01 筆，實際上僅 71 筆

# %% [markdown]
# stscd是狀態碼，可推論通常是卡片狀態異常才會有值

# %%
print(f'在stscd不缺失(狀態異常)的情況下，正常交易筆數為 {len(train[(~train.stscd.isna()) & (train.label==0)])} 筆，異常交易筆數為 {len(train[(~train.stscd.isna()) & (train.label==1)])} 筆')
# Out:
# 在stscd不缺失(狀態異常)的情況下，正常交易筆數為 12852 筆，異常交易筆數為 10479 筆

# %%
na_name = (train.isna().sum()[train.isna().sum()>0].index)
na_name
# Out:
# Index(['etymd', 'mcc', 'stocn', 'scity', 'stscd', 'hcefg', 'csmcu'], dtype='object')

# %% [markdown]
# csmcu

# %%
def hot_deck_imputation(data, variable, distance_metric='euclidean'):
    # 创建一个新的数据框用于存储插补后的值
    imputed_data = data.copy()

    # 找到含有缺失值的行
    missing_rows = data[data[variable].isna()]

    # 找到没有缺失值的行
    complete_rows = data[~data[variable].isna()]

    for index, missing_row in missing_rows.iterrows():
        # 只在存在相似的观测值时进行插补
        if not complete_rows.empty:
            # 计算缺失行与没有缺失值的行之间的距离
            distances = pairwise_distances(missing_row[variable].values.reshape(1, -1), complete_rows[[variable]], metric=distance_metric)

            # 找到最接近的观测值的索引
            nearest_index = distances.argmin()

            # 从最接近的观测值中获取值并用于填充缺失值
            imputed_value = complete_rows.iloc[nearest_index][variable]

            # 将 imputed_value 填充到缺失值的行
            imputed_data.at[index, variable] = imputed_value

    return imputed_data

# %%
# 在train数据集上进行热平台插补，假设缺失值在 'csmcu' 列
imputed_train = hot_deck_imputation(train, 'csmcu')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\cool8\Desktop\AI_CUP competition\feature_engineering.ipynb 儲存格 19 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y162sZmlsZQ%3D%3D?line=0'>1</a> # 在train数据集上进行热平台插补，假设缺失值在 'csmcu' 列
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y162sZmlsZQ%3D%3D?line=1'>2</a> imputed_train = hot_deck_imputation(train, 'csmcu')
#
# c:\Users\cool8\Desktop\AI_CUP competition\feature_engineering.ipynb 儲存格 19 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y162sZmlsZQ%3D%3D?line=10'>11</a> for index, missing_row in missing_rows.iterrows():
#      <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y162sZmlsZQ%3D%3D?line=11'>12</a>     # 只在存在相似的观测值时进行插补
#      <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y162sZmlsZQ%3D%3D?line=12'>13</a>     if not complete_rows.empty:
#      <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y162sZmlsZQ%3D%3D?line=13'>14</a>         # 计算缺失行与没有缺失值的行之间的距离
# ---> <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y162sZmlsZQ%3D%3D?line=14'>15</a>         distances = pairwise_distances(missing_row[variable].values.reshape(1, -1), complete_rows[[variable]], metric=distance_metric)
#      <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y162sZmlsZQ%3D%3D?line=16'>17</a>         # 找到最接近的观测值的索引
#      <a href='vscode-notebook-cell:/c%3A/Users/cool8/Desktop/AI_CUP%20competition/feature_engineering.ipynb#Y162sZmlsZQ%3D%3D?line=17'>18</a>         nearest_index = distances.argmin()
#
# AttributeError: 'float' object has no attribute 'values'

# %%
print(train[train.csmcu.isna()&(train.label==1)].hcefg.value_counts().sort_index().sum())
print(train[train.csmcu.isna()&(train.label==0)].hcefg.value_counts().sort_index().sum())
# Out:
# 227
# 212664
# 0.0010662733511515282

# %%
print(train[train.csmcu.isna()&(train.label==0)].hcefg.value_counts().sort_index())
print(train[train.csmcu.isna()].hcefg.value_counts().sort_index()/sum(train[train.csmcu.isna()].hcefg))

#print(train[train.label==0].hcefg.value_counts().sort_index())
# Out:
# hcefg
# 0.0     22769
# 2.0         8
# 3.0      1692
# 4.0        88
# 5.0       249
# 6.0    182459
# 8.0      4525
# 9.0       874
# Name: count, dtype: int64
# hcefg
# 0.0     757616
# 1.0     184844
# 2.0        112
# 3.0      51414
# 4.0        490
# 5.0       2479
# 6.0    7291472
# 7.0      10696
# 8.0      35635
# 9.0      35258
# Name: count, dtype: int64

# %%
print(train[train.csmcu.isna()].hcefg.value_counts().sort_index())
print(train.hcefg.value_counts().sort_index())
# Out:
# hcefg
# 0.0     22876
# 2.0        20
# 3.0      1718
# 4.0        88
# 5.0       249
# 6.0    182529
# 8.0      4527
# 9.0       884
# Name: count, dtype: int64
# hcefg
# 0.0      758808
# 1.0      184851
# 2.0         159
# 3.0       51551
# 4.0         490
# 5.0        2479
# 6.0     7321872
# 7.0       10696
# 8.0       35638
# 9.0       35320
# 10.0          6
# Name: count, dtype: int64

# %%
for idx in na_name:
    print(idx)
    sns.countplot(x= idx, data=train[train['label']==0])
    plt.title(f'Distribution of {idx} in Normal Data')
    plt.show()

    sns.countplot(x=idx, data=train[train['label']==1])
    plt.title(f'Distribution of {idx} in Abnormal Data')
    plt.show()

# %% [markdown]
# 計算各筆資料的缺失值總數

# %%
print((train.isna()).sum(axis=1).value_counts())
print((public.isna()).sum(axis=1).value_counts())
# Out:
# 1    8140512
# 3     284589
# 4     192521
# 2      28368
# 0      21720
# 5      20816
# Name: count, dtype: int64
# 1    562574
# 3     19283
# 4     13178
# 2      2234
# 5      1473
# 0      1440
# Name: count, dtype: int64

# %% [markdown]
# ### 抽樣看看

# %%
np.random.seed(43)
# 指定要抽取的样本大小（假设抽取1000个样本）
sample_size = 100000

# 随机抽样
random_sample = train.sample(n=sample_size)

# %%
print(train.isna().sum()[train.isna().sum()>0]/sum(train.isna().sum()[train.isna().sum()>0]))
print(public.isna().sum()[public.isna().sum()>0]/sum(public.isna().sum()[public.isna().sum()>0]))
print(random_sample.isna().sum()[random_sample.isna().sum()>0]/sum(random_sample.isna().sum()[random_sample.isna().sum()>0]))
# Out:
# etymd    0.020499
# mcc      0.000458
# stocn    0.000060
# scity    0.026807
# stscd    0.873052
# hcefg    0.028882
# csmcu    0.050242
# dtype: float64
# etymd    0.020185
# mcc      0.000517
# stocn    0.000102
# scity    0.026906
# stscd    0.874060
# hcefg    0.028765
# csmcu    0.049465
# dtype: float64
# etymd    0.020351
# mcc      0.000568
# stocn    0.000079
# scity    0.026520
# stscd    0.871472
# hcefg    0.029902
# csmcu    0.051109
# dtype: float64

# %%
#random_sample.mcc.isna().sum()
#train.mcc.isna().sum()
#train[train.label==1].etymd.isna().sum()
#train[train.label==0].etymd.isna().sum()
71/203384
# Out:
# 0.00034909334067576605

# %%
a = 1
print(train[train.label==a].isna().sum()[train.isna().sum()>0]/len(train[train.label==a]))
#print(public[public.label==1].isna().sum()[public.isna().sum()>0]/sum(public[public.label==1].isna().sum()[public.isna().sum()>0]))
print(random_sample[random_sample.label==a].isna().sum()[random_sample.isna().sum()>0]/len(random_sample[random_sample.label==a]))
# Out:
# etymd    0.002217
# mcc      0.000062
# stocn    0.000781
# scity    0.019451
# stscd    0.672828
# hcefg    0.005464
# csmcu    0.012083
# dtype: float64
# etymd    0.000000
# mcc      0.000000
# stocn    0.002801
# scity    0.005602
# stscd    0.644258
# hcefg    0.000000
# csmcu    0.002801
# dtype: float64

# %%
(train[train.label==a].isna().sum()[train.isna().sum()>0]/len(train[train.label==a])).drop('stscd').plot(kind='bar', color='skyblue') 
plt.title('Proportion of Missing Value in Train Data')
plt.show()

(random_sample[random_sample.label==a].isna().sum()[random_sample.isna().sum()>0]/len(random_sample)).drop('stscd').plot(kind='bar', color='skyblue') 
plt.title(f'Proportion of Missing Value in {len(random_sample)}samples Data')
plt.show()

# %%
(train.isna().sum()[train.isna().sum()>0]/sum(train.isna().sum()[train.isna().sum()>0])).plot(kind='bar', color='skyblue') 
plt.title('Proportion of Missing Value in Train Data')
plt.show()

(public.isna().sum()[public.isna().sum()>0]/sum(public.isna().sum()[public.isna().sum()>0])).plot(kind='bar', color='skyblue') 
plt.title('Proportion of Missing Value in Public Data')
plt.show()

(random_sample.isna().sum()[random_sample.isna().sum()>0]/sum(random_sample.isna().sum()[random_sample.isna().sum()>0])).plot(kind='bar', color='skyblue') 
plt.title(f'Proportion of Missing Value in {len(random_sample)} samples Data')
plt.show()

# %%
print((train.isna()).sum(axis=1).value_counts())
print((train[train['label']==0].isna()).sum(axis=1).value_counts())
print((train[train['label']==1].isna()).sum(axis=1).value_counts())

# %%
missing_counts_normal = (train[train['label'] == 0].isna()).sum(axis=1).value_counts()
missing_counts_abnormal = (train[train['label'] == 1].isna()).sum(axis=1).value_counts()
# 绘制直方图
#plt.figure(figsize=(10, 6))
plt.bar(missing_counts_normal.index, missing_counts_normal.values)
plt.xlabel('Missing Value Count')
plt.ylabel('Frequency')
plt.title('Missing Value Count Distribution in Normal Transactions')
plt.show()

plt.bar(missing_counts_abnormal.index, missing_counts_abnormal.values)
plt.xlabel('Missing Value Count')
plt.ylabel('Frequency')
plt.title('Missing Value Count Distribution in Abnormal Transactions')
plt.show()

# %%
missing_counts = (public.isna()).sum(axis=1).value_counts()
# 绘制直方图
#plt.figure(figsize=(10, 6))
plt.bar(missing_counts.index, missing_counts.values)
plt.xlabel('Missing Value Count')
plt.ylabel('Frequency')
plt.title('Missing Value Count Distribution in Normal Transactions')
plt.show()

# %% [markdown]
# #### etymd

# %%
print(train[train['label']==0]['etymd'].isna().sum() ,train[train['label']==1]['etymd'].isna().sum())

print(train[train['label']==0]['etymd'].isna().sum()/8656497 ,train[train['label']==1]['etymd'].isna().sum()/32029)
# Out:
# 203384 71
# 0.02349495413675994 0.002216741078397702

# %%
train[train['label']==0]['etymd'].value_counts().sort_index()/sum(train[train['label']==0]['etymd'].value_counts().sort_index())

# %%
print(train[train['label']==0]['etymd'].value_counts().sort_index()/sum(train[train['label']==0]['etymd'].value_counts().sort_index()))
print(train[train['label']==1]['etymd'].value_counts().sort_index()/sum(train[train['label']==1]['etymd'].value_counts().sort_index()))

# %%
sns.countplot(x='etymd', data=train[train['label']==0])
plt.title('Distribution of etymd in Normal Data')
plt.show()

sns.countplot(x='etymd', data=train[train['label']==1])
plt.title('Distribution of etymd in Abnormal Data')
plt.show()

# %% [markdown]
# 填補+填補後的分布

# %%
train['etymd'] = train['etymd'].fillna(-1)

# %%
sns.countplot(x='etymd', data=train[train['label']==0])
plt.title('Distribution of etymd in Normal Data')
plt.show()

sns.countplot(x='etymd', data=train[train['label']==1])
plt.title('Distribution of etymd in Abnormal Data')
plt.show()

# %% [markdown]
# ### mcc

# %%
print(train[train['label']==0]['mcc'].isna().sum() ,train[train['label']==1]['mcc'].isna().sum())

print(train[train['label']==0]['mcc'].isna().sum()/8656497 ,train[train['label']==1]['mcc'].isna().sum()/32029)

# %%
print(train[train['label']==0]['mcc'].value_counts())
print(train[train['label']==1]['mcc'].value_counts())
# Out:
# mcc
# 320.0    1262155
# 276.0    1140977
# 282.0     659604
# 272.0     516844
# 275.0     379262
#           ...
# 204.0          1
# 30.0           1
# 74.0           1
# 58.0           1
# 391.0          1
# Name: count, Length: 450, dtype: int64
# mcc
# 324.0    6049
# 326.0    2078
# 317.0    2063
# 325.0    1842
# 323.0    1601
#          ...
# 208.0       1
# 150.0       1
# 256.0       1
# 140.0       1
# 113.0       1
# Name: count, Length: 261, dtype: int64

# %%
nmcc_count   = train[train['label']==0].mcc.value_counts()
abnmcc_count = train[train['label']==1].mcc.value_counts()

# %%
abnmcc_count.head(10).index

# %%
for x in abnmcc_count.head(10).index:
    print(nmcc_count.index.get_loc(x))
print('--------------------')
for x in nmcc_count.head(10).index:
    print(abnmcc_count.index.get_loc(x))

# %%
abnmcc_count[nmcc_count.head(10).index]

# %%
plt.bar(nmcc_count[nmcc_count>100000].index, nmcc_count[nmcc_count>100000].values)
plt.xlabel('mcc')
plt.ylabel('Frequency')
plt.title('mcc Count Distribution in Normal Transactions')
plt.show()

# %%
plt.bar(abnmcc_count[abnmcc_count>370].index, abnmcc_count[abnmcc_count>370].values)
plt.xlabel('mcc')
plt.ylabel('Frequency')
plt.title('mcc Count Distribution in Normal Transactions')
plt.show()

# %%
nmcc_count

plt.bar(nmcc_count.index, nmcc_count.values)
plt.xlabel('mcc')
plt.ylabel('Frequency')
plt.title('mcc Count Distribution in Normal Transactions')
plt.show()

# %% [markdown]
# #### stscd

# %%
print(train[train['label']==0]['stscd'].value_counts())
print(train[train['label']==1]['stscd'].value_counts())

# %%
sns.countplot(x='stscd', data=train[train['label']==0])
plt.title('Distribution of stscd in Normal Data')
plt.show()

sns.countplot(x='stscd', data=train[train['label']==1])
plt.title('Distribution of stscd in Abnormal Data')
plt.show()

# %% [markdown]
# 填補+填補後的分布

# %%
train['stscd'] = train['stscd'].fillna(-1)

# %%
sns.countplot(x='stscd', data=train[train['label']==0])
plt.title('Distribution of stscd in Normal Data')
plt.show()

sns.countplot(x='stscd', data=train[train['label']==1])
plt.title('Distribution of stscd in Abnormal Data')
plt.show()

# %% [markdown]
# ## EDA

# %%
df.describe()
# Out:
#               locdt         loctm         contp         etymd           mcc  \
# count  9.288708e+06  9.288708e+06  9.288708e+06  9.288708e+06  9.288708e+06
# mean   2.943696e+01  1.430691e+05  4.904868e+00  4.581256e+00  3.172410e+02
# std    1.729148e+01  5.386045e+04  4.741711e-01  2.395982e+00  6.911332e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    1.400000e+01  1.041240e+05  5.000000e+00  4.000000e+00  2.760000e+02
# 50%    3.000000e+01  1.452160e+05  5.000000e+00  5.000000e+00  2.890000e+02
# 75%    4.400000e+01  1.848280e+05  5.000000e+00  5.000000e+00  3.250000e+02
# max    5.900000e+01  2.359590e+05  6.000000e+00  1.000000e+01  5.010000e+02
#
#               conam          ecfg         insfg         iterm         bnsfg  \
# count  9.288708e+06  9.288708e+06  9.288708e+06  9.288708e+06  9.288708e+06
# mean   1.428644e+03  5.739214e-01  1.065735e-02  6.105607e-02  1.293398e-03
# std    9.670781e+03  4.945055e-01  1.026829e-01  7.362866e-01  3.594059e-02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.050000e+02  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    3.150000e+02  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    9.010000e+02  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# max    5.051970e+06  1.000000e+00  1.000000e+00  3.000000e+01  1.000000e+00
#
#               flam1         stocn         scity         stscd         ovrlt  \
# count  9.288708e+06  9.288708e+06  9.288708e+06  9.288708e+06  9.288708e+06
# mean   1.428170e+03  8.396169e+00  1.388305e+04 -9.947255e-01  9.771757e-03
# std    9.669248e+03  2.785559e+01  3.870826e+03  1.025132e-01  9.836804e-02
# min    0.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00  0.000000e+00
# 25%    1.050000e+02  0.000000e+00  1.345100e+04 -1.000000e+00  0.000000e+00
# 50%    3.150000e+02  0.000000e+00  1.575900e+04 -1.000000e+00  0.000000e+00
# 75%    9.030000e+02  0.000000e+00  1.575900e+04 -1.000000e+00  0.000000e+00
# max    5.032773e+06  1.340000e+02  1.734000e+04  4.000000e+00  1.000000e+00
#
#               flbmk         hcefg         csmcu         csmam     flg_3dsmk  \
# count  9.288708e+06  9.288708e+06  9.288708e+06  9.288708e+06  9.288708e+06
# mean   3.030561e-04  5.143982e+00  6.557982e+01  2.822580e+03  8.614072e-02
# std    1.740587e-02  2.157913e+00  1.696971e+01  1.105215e+05  2.805717e-01
# min    0.000000e+00 -1.000000e+00 -1.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  6.000000e+00  7.000000e+01  9.400000e+01  0.000000e+00
# 50%    0.000000e+00  6.000000e+00  7.000000e+01  2.890000e+02  0.000000e+00
# 75%    0.000000e+00  6.000000e+00  7.000000e+01  9.820000e+02  0.000000e+00
# max    1.000000e+00  1.000000e+01  8.500000e+01  7.473480e+07  1.000000e+00
#
#               label
# count  9.288708e+06
# mean  -6.116599e-02
# std    2.536159e-01
# min   -1.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.000000e+00

# %%
#public.columns
numeric_variable = ['locdt', 'loctm', 'conam', 'iterm','flam1', 'csmam']
df[numeric_variable].describe()
# Out:
#               locdt         loctm         conam         iterm         flam1  \
# count  9.288708e+06  9.288708e+06  9.288708e+06  9.288708e+06  9.288708e+06
# mean   2.943696e+01  1.430691e+05  1.428644e+03  6.105607e-02  1.428170e+03
# std    1.729148e+01  5.386045e+04  9.670781e+03  7.362866e-01  9.669248e+03
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.400000e+01  1.041240e+05  1.050000e+02  0.000000e+00  1.050000e+02
# 50%    3.000000e+01  1.452160e+05  3.150000e+02  0.000000e+00  3.150000e+02
# 75%    4.400000e+01  1.848280e+05  9.010000e+02  0.000000e+00  9.030000e+02
# max    5.900000e+01  2.359590e+05  5.051970e+06  3.000000e+01  5.032773e+06
#
#               csmam
# count  9.288708e+06
# mean   2.822580e+03
# std    1.105215e+05
# min    0.000000e+00
# 25%    9.400000e+01
# 50%    2.890000e+02
# 75%    9.820000e+02
# max    7.473480e+07

# %%
df.conam.sort_values(ascending = False)[df.conam.sort_values(ascending = False)>1000000].plot(kind='hist')
# df.conam.plot(kind='box')
# plt.show()
# Out:
# <Axes: ylabel='Frequency'>

# %%
A = df[df.label==0].locdt.value_counts().sort_index()
B = df[df.label==1].locdt.value_counts().sort_index()
(A/sum(A)).plot()
(B/sum(B)).plot()
for locdt_value in range(min(df['locdt']), max(df['locdt']) + 1, 7):
    plt.axvline(x=locdt_value, color='red', linestyle='--', linewidth=1)
plt.show()

#正常交易高峰 4,13,20,26,33,35,40,47
#異常交易高峰 ,40,42,46,50

# %%
df.chid.value_counts()
# Out:
# chid
# f200cd7e88bd814ad8bdf48c02216695ce72375f95873d63cd4bf724ad3e7a11    9674
# b59fa05aa098dee0422e892af2e21e66f3f554d05cf950ef46c35fecf105701c    2868
# 20e72d586a7c7e4acf0f5f52488d3a82764d310a5477363f3e6492e12fc3e42d    2824
# 75945c8b1b7af88340ffe4169b39341dfded2c07248d36e91b3e2a0852c7bab7    2543
# 4b3f553fcb079b258f2a6a0c9a09a5b467c5138cda9c740d7b5e7059b00e9752    1743
#                                                                     ...
# a94b2c35307a165823e38040f30c633720b922cc5e242b6bf963fb176b724029       1
# cd7eeb3797614c101643337f61675d9ca3f185ddb165aaa122e80f6b27810c19       1
# 67ea8f7ace058835617668f5689b213849188d1d3eefb40c47ab10459403dd23       1
# 35b2bad388219d5fc7ecfc6089950e0811ff4c2c8945c78a28d2433bc4f80d17       1
# 85a538fe0cb00a82ebdb948f1a8b45bfea5005dfcf7dcb3c89826033afcdf427       1
# Name: count, Length: 487830, dtype: int64

# %% [markdown]
# ### 分析用戶跟卡號的關係

# %% [markdown]
# 一張卡(cano)有多個顧客ID(chid) -> 合併

# %%
for x in sorted(df.cards.unique()):
    print(f'{x} 張卡\t　總數 : {len(df[df.cards==x])}, \t 比例:{sum(df[df.cards==x].label>0)/len(df[df.cards==x]) }',)
# Out:
# 1 張卡	　總數 : 5894332, 	 比例:0.004777640621532686
# 2 張卡	　總數 : 2361544, 	 比例:0.0010903883222163127
# 3 張卡	　總數 : 703139, 	 比例:0.0013269069131423518
# 4 張卡	　總數 : 212371, 	 比例:0.001299612470629229
# 5 張卡	　總數 : 70607, 	 比例:0.000807285396632062
# 6 張卡	　總數 : 25558, 	 比例:0.0007825338445887784
# 7 張卡	　總數 : 9157, 	 比例:0.000764442503003167
# 8 張卡	　總數 : 5040, 	 比例:0.0
# 9 張卡	　總數 : 2614, 	 比例:0.0
# 10 張卡	　總數 : 1019, 	 比例:0.0
# 11 張卡	　總數 : 226, 	 比例:0.0
# 12 張卡	　總數 : 21, 	 比例:0.0
# 13 張卡	　總數 : 63, 	 比例:0.0
# 20 張卡	　總數 : 474, 	 比例:0.0
# 27 張卡	　總數 : 2543, 	 比例:0.0

# %%
cano_chid_counts = df.groupby('cano')['chid'].nunique()
cano_chid_counts
# Out:
# cano
# 000004e90549c10a46912120949a36bbe9c92fb02daa27703f232957db971a3e    1
# 00002522901695edfbc8be6728ad6b5cd63f30a9a9b9c9827c2fbb8783119da4    1
# 0000635e95f06e3542a664112f7dc9610e11ca4de383b1eb72679534e28dabe4    1
# 000085a95392a936a8f34bdaa9d05f7df0a6c2225cb776895e36dfe1194f52fd    1
# 0000d1a82b1e29f7902725efd722923c726b5d826d6df3ea75e717a921d68e96    1
#                                                                    ..
# ffff679504aea1ca2294e4a185bdbdf7d166224f83c42ed4cd4521774fb62aed    1
# ffff78f6346f8ae69e0e0501921f429cc3c7f950df85a8c66f09af58eaf2992d    1
# ffff84cd1101eec24039332bb90193b9c6f4295e0489851c31b54b8a392a87c9    1
# ffff8fed185e7a8295d6081fcac3a78cdd72d08903b95c081d63069a7aec8fbc    1
# ffffa5b23e42f7b181116352663f282cd5e2f94a0bf5b6019c8dbbaa9030a8af    1
# Name: chid, Length: 627785, dtype: int64

# %% [markdown]
# 看一個人拿幾張卡

# %%
# 創建一個示例 DataFrame
data = {'chid': ['A', 'A', 'A', 'A', 'B', 'B', 'C'],
        'cano': ['101', '102', '103', '102', '201', '201', '301'],
        'locdt': [1, 2, 3, 1.5,  1, 2, 1],
        'loctm': [120000, 150000,300, 917, 100000, 130000, 90000]}

data = pd.DataFrame(data)

# 對數據按照 chid 和時間進行排序
data = data.sort_values(['chid', 'locdt', 'loctm'])

data['cards_before_time'] = data.groupby('chid')['cano'].expanding().apply(lambda x: x.nunique()).reset_index(level=0, drop=True)

# 計算每個用戶在某個時間之前（含該時間）共拿了幾張不同的卡號
# data['cards_before_time'] = data.groupby(['chid', 'locdt'])['cano'].transform('nunique')

print(data[['chid', 'locdt', 'loctm', 'cano', 'cards_before_time']])
# Out:
#   chid  locdt   loctm cano  cards_before_time
# 0    A    1.0  120000  101                  3
# 3    A    1.5     917  102                  3
# 1    A    2.0  150000  102                  3
# 2    A    3.0     300  103                  3
# 4    B    1.0  100000  201                  1
# 5    B    2.0  130000  201                  1
# 6    C    1.0   90000  301                  1

# %%
data.groupby('chid')['cano'].cumcount()+1
# Out:
# 0    1
# 1    2
# 2    3
# 3    1
# 4    2
# 5    1
# dtype: int64

# %% [markdown]
# ### 時間分布
# 晚上8:00~隔天3:00是盜刷好發時段

# %%
df[df.label==1].h_loctm.value_counts().sort_index()
# Out:
# h_loctm
# 0     1859
# 1     1620
# 2     1504
# 3     1252
# 4      936
# 5      766
# 6      627
# 7      676
# 8      661
# 9      885
# 10    1101
# 11    1186
# 12    1023
# 13    1214
# 14    1479
# 15    1533
# 16    1615
# 17    1649
# 18    1543
# 19    1345
# 20    1747
# 21    1971
# 22    1854
# 23    1983
# Name: count, dtype: int64

# %%
4/24
# Out:
# 0.16666666666666666

# %%
df[df.label==0].h_loctm.plot(kind='hist',bins = 24)
plt.show()
df[df.label==1].h_loctm.plot(kind='hist',bins = 24)
plt.axvline(x=3.89, color='black', linestyle='--', linewidth=1)
plt.axvline(x=18.95833333333, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# 分鐘跟秒都沒差

# %%
df[df.label==0].m_loctm.plot(kind='hist',bins=60)
plt.show()

df[df.label==1].m_loctm.plot(kind='hist',bins=60)
plt.show()

# %%
df[df.label==0].s_loctm.plot(kind='hist',bins=60)
plt.show()

df[df.label==1].s_loctm.plot(kind='hist',bins=60)
plt.show()

# %%
df[df.label==0].mins_loctm.plot(kind='hist',bins = 24)
plt.show()
df[df.label==1].mins_loctm.plot(kind='hist',bins = 24)
plt.title('21:00~04:00 occurs frequently')
plt.show()

# %%
chid_cano_counts = df.groupby('chid')['cano'].nunique()
df['cards'] = df.chid.map(chid_cano_counts)

# %% [markdown]
# csmcu 取對數後接近常態分配

# %%
np.log10(df[(df.csmcu==70)&(df.conam>=0)].conam+1).plot(kind='hist')
plt.show()
np.log10(df[(df.csmcu==-1)&(df.conam>=0)].conam+1).plot(kind='hist')
plt.show()

# %% [markdown]
# ### 看MCC

# %%
#df.mcc.value_counts()[df.mcc.value_counts()>10000].index
for x in (df.mcc.value_counts()[df.mcc.value_counts()>100000].index):
    print(x, round(df[(df.label>=0)&(df.mcc==x)].label.sum()/len(df[(df.label>=0)&(df.mcc==x)]),4))
# Out:
# 320.0 0.0005
# 276.0 0.0002
# 282.0 0.001
# 272.0 0.0004
# 275.0 0.0006
# 273.0 0.0002
# 288.0 0.0001
# 375.0 0.0001
# 289.0 0.0
# 322.0 0.0005
# 217.0 0.0024
# 499.0 0.0004
# 215.0 0.0003
# 493.0 0.0
# 406.0 0.0068
# 494.0 0.0
# 324.0 0.0572
# 413.0 0.0047
# 309.0 0.001

# %%
# 散點圖
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Time', y='label', hue='Class', data=df)
plt.title('Scatter Plot of Time vs Amount')
plt.show()

# %% [markdown]
# ### Cluster分析

# %%
# change to percentage
ecfg_pct = df.loc[:,['cano','ecfg']][df.label!=-1].groupby('cano').mean()

# clustering by k-means with elbow method

sse = {}

for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(ecfg_pct)
#   oversea_pct["clusters"] = kmeans.labels_
#   print(oversea_pct["clusters"])
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center

plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()
# Out:
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] 系統找不到指定的檔案。
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\cool8\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\cool8\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\cool8\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
##k = 3 
kmeans = KMeans(n_clusters=3, max_iter=1000).fit(ecfg_pct)
ecfg_pct["clusters"] = kmeans.labels_
ecfg_pct.head(20)
# Out:
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#                                                         ecfg  clusters
# cano
# 000004e90549c10a46912120949a36bbe9c92fb02daa277...  0.000000         0
# 00002522901695edfbc8be6728ad6b5cd63f30a9a9b9c98...  1.000000         1
# 0000635e95f06e3542a664112f7dc9610e11ca4de383b1e...  0.833333         1
# 000085a95392a936a8f34bdaa9d05f7df0a6c2225cb7768...  0.000000         0
# 0000d1a82b1e29f7902725efd722923c726b5d826d6df3e...  0.000000         0
# 0000e2fbf64f4865fe66e20a0a63f94af5abc43807123e1...  1.000000         1
# 0000fd2e52c5ec225c8114313caae6982e5957d789d6e3a...  0.444444         2
# 0001068bc5c324226b191cbb93d310488c0775facae66b5...  0.000000         0
# 00010bf5a87771976d5839f07e4cb09d7b074705bcd9b01...  0.000000         0
# 00011b8e4b70ffa858af01f70e3127ea366776b89441925...  0.500000         2
# 00011fe81f2d532cbdc0f7cf2a1c5fbf5fdb68dbb9934e0...  0.555556         2
# 000126c7073aad3be084f7a2243fbc4b2838a2f7a8b228d...  0.000000         0
# 000143b47ca3d5b94b1112be2dff968df8bec10f853e914...  0.500000         2
# 00016317dffa70d82efe9f393b5876e394eb820cfdc42e0...  0.200000         0
# 000165494682d1e7d3412a9cc5ed39025a2877bbc72152b...  0.133333         0
# 00016894219e9795084ac93dc1c37912c5f38ef10722050...  0.000000         0
# 0001797211c4d3a0568182cbf3efe2e862042f1322b34f8...  0.500000         2
# 0001823ef87c2ff53cb04b9b3557d1fb257989e20701668...  0.400000         2
# 000187f144e555cab6bc1e65f4317f7bf452ead35f2aeb7...  1.000000         1
# 0001a3d9bbd9085fbd4f04a360c81a20ad8ab0705d5b447...  1.000000         1

# %%
# change to percentage
ecfg_pct = df.loc[:,['cano','ecfg']][df.label!=-1].groupby('cano').mean()

sse = {}

for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(ecfg_pct)
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center

plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %%
df.columns
# Out:
# Index(['txkey', 'locdt', 'loctm', 'chid', 'cano', 'contp', 'etymd', 'mchno',
#        'acqic', 'mcc', 'conam', 'ecfg', 'insfg', 'iterm', 'bnsfg', 'flam1',
#        'stocn', 'scity', 'stscd', 'ovrlt', 'flbmk', 'hcefg', 'csmcu', 'csmam',
#        'flg_3dsmk', 'label', 'weekday', 'h_loctm', 'm_loctm', 's_loctm',
#        'mins_loctm'],
#       dtype='object')

# %% [markdown]
# 看數值型變數的相關性(不太相關)

# %%
numeric_variable = ['weekday','mins_loctm','csmam','conam','flam1','iterm']
# df[numeric_variable].corr

correlationNonFraud   = df[df.label== 0][numeric_variable].corr()
correlationFraud      = df[df.label== 1][numeric_variable].corr()

#training的corr
sns.heatmap(df[df.label== 0][numeric_variable].corr(), cmap='coolwarm', annot=True)
plt.show()

#正常的corr
sns.heatmap(correlationNonFraud, cmap='coolwarm', annot=True)
plt.show()

#盜刷的corr
sns.heatmap(correlationFraud, cmap='coolwarm', annot=True)
plt.show()

# %%
cards = df[df.label!=-1].cano.unique()

A = df[df.label==-1].cano.isin(cards).sum()
print('publict重複用戶總數：',A,'　比例：',A/len(df[df.label==-1]))
# Out:
# publict重複用戶總數： 586371 　比例： 0.9769886467771443

# %%
print(len(df[(df.ecfg==0)&(df.label==1)])/len(df[(df.ecfg==0)&(df.label!=-1)]))
print(len(df[(df.ecfg==1)&(df.label==1)])/len(df[(df.ecfg==1)&(df.label!=-1)]))
# Out:
# 0.0011285825841717704
# 0.005600335794782061

# %%
A = df[df.cano.isin(df[df.label==1].cano)&(df.label!=-1)].sort_values(['locdt','loctm']).groupby('cano')['label'].cumsum()+1
A
# Out:
# 2758173    1.0
# 1679610    1.0
# 3888207    2.0
# 2411515    1.0
# 7757530    2.0
#           ...
# 7959666    2.0
# 6724745    2.0
# 6854036    3.0
# 3927757    4.0
# 2493909    4.0
# Name: label, Length: 72464, dtype: float64

# %%
df[(df.scity.isin(df.scity.value_counts().head(10).index))&df.stocn==0].label.value_counts()
# Out:
# label
#  0.0    8481444
# -1.0     586117
#  1.0      22676
# Name: count, dtype: int64

# %%
df.cano.value_counts()
# Out:
# cano
# f740c6359369dd973f53180fa50db3ca96d81c9054dad7086cad18d460daae97    4680
# e12336ad8f5aa0bcd0271a46869cf81cafbd7591f7eeb542b6a50c9b7c3e0142    3967
# 27f62a67d87256dbff64aca05502d8a7d7a9e8248c531bc305776e4a74d15751    2868
# 5606f28867295bd1c4ac3a784b36896d7e3f70a49bfa4f3f591721d00c00075a    2822
# 8b192f8e96d3844745a47ea0a0b1f29adc86a6f6010eed4fba56b1b46148fdb8    1554
#                                                                     ...
# 43c6600a43499c22ac66922165dcff20a8b107451e0816f444c654de9806f4a6       1
# 69fe6fbbd2016b40e4b16f97953904ff119c43ea138b4f9ebd98f2396eb50490       1
# 9d1028a61091a5296b200a69ca3aa2bbdba8d52e3e223f7b346d0acaa7fc5eba       1
# 4824a7977a544a565819d0d5cd75c9b76aa849e37f4078529ceb5db5135f2662       1
# 2990660b8172986c57c793f16bb565ae29cd7572b50f05afbe860cf7c9125035       1
# Name: count, Length: 627785, dtype: int64

# %%
cano = df.cano.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\preprocessing\Der_EDA.ipynb 儲存格 116 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cool8/Documents/GitHub/fraud-detection-E.SUN/preprocessing/Der_EDA.ipynb#Y326sZmlsZQ%3D%3D?line=0'>1</a> cards
#       <a href='vscode-notebook-cell:/c%3A/Users/cool8/Documents/GitHub/fraud-detection-E.SUN/preprocessing/Der_EDA.ipynb#Y326sZmlsZQ%3D%3D?line=1'>2</a> # cards = df.cano.unique()
#
# NameError: name 'cards' is not defined

# %%
def calculate_mode(x):
    # 對每個cano計算當前時間之前的資料的眾數
    return x.loc[x['mins_loctm'] <= x['mins_loctm'].max(), 'mchno'].mode()

cano_array = df.cano.unique()
for x in cano_array:
    df_sort[df.cano== x].apply(calculate_mode)


# 使用 groupby 和 apply 進行計算
result = df_sort.cano.groupby(['cano', 'mins_loctm']).apply(calculate_mode).reset_index()

# 重命名結果列
result.columns = ['cano', 'mode_mchno']

# 將結果合併到原始 DataFrame
df_sort = pd.merge(df_sort, result, on='cano', how='left')

# %%
def calculate_mode(x):
    # 對每個cano計算當前時間之前的資料的眾數
    return x.loc[x['mins_loctm'] <= x['mins_loctm'].max(), 'mchno'].mode()

# 使用 groupby 和 apply 進行計算
result = df_sort.groupby(['cano', 'mins_loctm']).apply(calculate_mode).reset_index()

# 重命名結果列
result.columns = ['cano', 'mode_mchno']

# 將結果合併到原始 DataFrame
df_sort = pd.merge(df_sort, result, on='cano', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\preprocessing\Der_EDA.ipynb 儲存格 119 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/cool8/Documents/GitHub/fraud-detection-E.SUN/preprocessing/Der_EDA.ipynb#Y305sZmlsZQ%3D%3D?line=2'>3</a>     return x.loc[x['mins_loctm'] <= x['mins_loctm'].max(), 'mchno'].mode()
#       <a href='vscode-notebook-cell:/c%3A/Users/cool8/Documents/GitHub/fraud-detection-E.SUN/preprocessing/Der_EDA.ipynb#Y305sZmlsZQ%3D%3D?line=4'>5</a> # 使用 groupby 和 apply 進行計算
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cool8/Documents/GitHub/fraud-detection-E.SUN/preprocessing/Der_EDA.ipynb#Y305sZmlsZQ%3D%3D?line=5'>6</a> result = df_sort.groupby(['cano', 'mins_loctm']).apply(calculate_mode).reset_index()
#       <a href='vscode-notebook-cell:/c%3A/Users/cool8/Documents/GitHub/fraud-detection-E.SUN/preprocessing/Der_EDA.ipynb#Y305sZmlsZQ%3D%3D?line=7'>8</a> # 重命名結果列
#       <a href='vscode-notebook-cell:/c%3A/Users/cool8/Documents/GitHub/fraud-detection-E.SUN/preprocessing/Der_EDA.ipynb#Y305sZmlsZQ%3D%3D?line=8'>9</a> result.columns = ['cano', 'mode_mchno']
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1766, in GroupBy.apply(self, func, *args, **kwargs)
#    1764 with option_context("mode.chained_assignment", None):
#    1765     try:
# -> 1766         result = self._python_apply_general(f, self._selected_obj)
#    1767     except TypeError:
#    1768         # gh-20949
#    1769         # try again, with .apply acting as a filtering
#    (...)
#    1773         # fails on *some* columns, e.g. a numeric operation
#    1774         # on a string grouper column
#    1776         return self._python_apply_general(f, self._obj_with_exclusions)
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1815, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1780 @final
#    1781 def _python_apply_general(
#    1782     self,
#    (...)
#    1787     is_agg: bool = False,
#    1788 ) -> NDFrameT:
#    1789     """
#    1790     Apply function f in python space
#    1791
#    (...)
#    1813         data after applying f
#    1814     """
# -> 1815     values, mutated = self.grouper.apply_groupwise(f, data, self.axis)
#    1816     if not_indexed_same is None:
#    1817         not_indexed_same = mutated
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\groupby\ops.py:905, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     903 # group might be modified
#     904 group_axes = group.axes
# --> 905 res = f(group)
#     906 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     907     mutated = True
#
# c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\preprocessing\Der_EDA.ipynb 儲存格 119 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/cool8/Documents/GitHub/fraud-detection-E.SUN/preprocessing/Der_EDA.ipynb#Y305sZmlsZQ%3D%3D?line=0'>1</a> def calculate_mode(x):
#       <a href='vscode-notebook-cell:/c%3A/Users/cool8/Documents/GitHub/fraud-detection-E.SUN/preprocessing/Der_EDA.ipynb#Y305sZmlsZQ%3D%3D?line=1'>2</a>     # 對每個cano計算當前時間之前的資料的眾數
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cool8/Documents/GitHub/fraud-detection-E.SUN/preprocessing/Der_EDA.ipynb#Y305sZmlsZQ%3D%3D?line=2'>3</a>     return x.loc[x['mins_loctm'] <= x['mins_loctm'].max(), 'mchno'].mode()
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\indexing.py:1330, in _LocIndexer._getitem_tuple(self, tup)
#    1328 with suppress(IndexingError):
#    1329     tup = self._expand_ellipsis(tup)
# -> 1330     return self._getitem_lowerdim(tup)
#    1332 # no multi-index, so validate all of the indexers
#    1333 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\indexing.py:1063, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1061             return section
#    1062         # This is an elided recursive call to iloc/loc
# -> 1063         return getattr(section, self.name)[new_key]
#    1065 raise IndexingError("not applicable")
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\indexing.py:1375, in _LocIndexer._getitem_axis(self, key, axis)
#    1373     return self._get_slice_axis(key, axis=axis)
#    1374 elif com.is_bool_indexer(key):
# -> 1375     return self._getbool_axis(key, axis=axis)
#    1376 elif is_list_like_indexer(key):
#    1377     # an iterable multi-selection
#    1378     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\indexing.py:1173, in _LocationIndexer._getbool_axis(self, key, axis)
#    1171 key = check_bool_indexer(labels, key)
#    1172 inds = key.nonzero()[0]
# -> 1173 return self.obj._take_with_is_copy(inds, axis=axis)
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\generic.py:4088, in NDFrame._take_with_is_copy(self, indices, axis)
#    4077 @final
#    4078 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4079     """
#    4080     Internal version of the `take` method that sets the `_is_copy`
#    4081     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4086     See the docstring of `take` for full explanation of the parameters.
#    4087     """
# -> 4088     result = self.take(indices=indices, axis=axis)
#    4089     # Maybe set copy if we didn't actually change the index.
#    4090     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\generic.py:4068, in NDFrame.take(self, indices, axis, **kwargs)
#    4063     # We can get here with a slice via DataFrame.__getitem__
#    4064     indices = np.arange(
#    4065         indices.start, indices.stop, indices.step, dtype=np.intp
#    4066     )
# -> 4068 new_data = self._mgr.take(
#    4069     indices,
#    4070     axis=self._get_block_manager_axis(axis),
#    4071     verify=True,
#    4072 )
#    4073 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4074     self, method="take"
#    4075 )
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\internals\managers.py:876, in BaseBlockManager.take(self, indexer, axis, verify)
#     873 n = self.shape[axis]
#     874 indexer = maybe_convert_indices(indexer, n, verify=verify)
# --> 876 new_labels = self.axes[axis].take(indexer)
#     877 return self.reindex_indexer(
#     878     new_axis=new_labels,
#     879     indexer=indexer,
#    (...)
#     882     copy=None,
#     883 )
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\indexes\base.py:1158, in Index.take(self, indices, axis, allow_fill, fill_value, **kwargs)
#    1156 values = self._values
#    1157 if isinstance(values, np.ndarray):
# -> 1158     taken = algos.take(
#    1159         values, indices, allow_fill=allow_fill, fill_value=self._na_value
#    1160     )
#    1161 else:
#    1162     # algos.take passes 'axis' keyword which not all EAs accept
#    1163     taken = values.take(
#    1164         indices, allow_fill=allow_fill, fill_value=self._na_value
#    1165     )
#
# File c:\Users\cool8\Documents\GitHub\fraud-detection-E.SUN\.venv\Lib\site-packages\pandas\core\algorithms.py:1319, in take(arr, indices, axis, allow_fill, fill_value)
#    1314     result = take_nd(
#    1315         arr, indices, axis=axis, allow_fill=True, fill_value=fill_value
#    1316     )
#    1317 else:
#    1318     # NumPy style
# -> 1319     result = arr.take(indices, axis=axis)
#    1320 return result
#
# KeyboardInterrupt:

# %%
df_sort

# %%
def calculate_mode(x):
    
    return x.loc[x['mins_loctm'] <= x['mins_loctm'].max(), 'mchno'].mode()

# 按照 cano 进行分组，并应用 calculate_mode 函数
result = df_sort.apply(calculate_mode).reset_index()

# %%
def calculate_mode(x):
    return x.loc[x['mins_loctm'] <= x['mins_loctm'].max(), 'mchno'].mode()

# 按照 cano 进行分组，并应用 calculate_mode 函数
# result = df_sort.groupby('cano').apply(calculate_mode).reset_index()

df.cano
# df_sort[df.cano==x]


# # 重命名结果列
# result.columns = ['cano','counts' ,'mode_mchno']

# # 输出结果
print(result)

df.cano.nunique()
# Out:
#                                                      cano  level_1  \
# 0       000004e90549c10a46912120949a36bbe9c92fb02daa27...        0
# 1       000004e90549c10a46912120949a36bbe9c92fb02daa27...        1
# 2       00002522901695edfbc8be6728ad6b5cd63f30a9a9b9c9...        0
# 3       00002522901695edfbc8be6728ad6b5cd63f30a9a9b9c9...        1
# 4       0000635e95f06e3542a664112f7dc9610e11ca4de383b1...        0
# ...                                                   ...      ...
# 889736  ffff8fed185e7a8295d6081fcac3a78cdd72d08903b95c...        0
# 889737  ffff8fed185e7a8295d6081fcac3a78cdd72d08903b95c...        1
# 889738  ffffa5b23e42f7b181116352663f282cd5e2f94a0bf5b6...        0
# 889739  ffffa5b23e42f7b181116352663f282cd5e2f94a0bf5b6...        1
# 889740  ffffa5b23e42f7b181116352663f282cd5e2f94a0bf5b6...        2
#
#                                                     mchno
# 0       09dd1fa2117349dc7fcbe7d88a8bbdab3eac610019010b...
# 1       c8131b6b345e94a8ff34642eae76ad4c71ce2027475ebc...
# 2       12c5b8c7cac508b0cf7214cee8c8ea9ebe1e23c5b0dd67...
# 3       216746c656372b82ca4960810749f3fd026977c793cebf...
# 4       e8d98e44151198526e079fdcc7f44c1e16be6f1fc2fb96...
# ...                                                   ...
# 889736  6c1fee0b78cb9da9ba0e4d3c91e75b3c195d66a974d9d6...
# 889737  9c18b9f9ea22011e9c30d284718fc42a4fa1272c356936...
# 889738  60a54fc232711d35dd53ae3c85afd669264bb97daee8a4...
# 889739  f9d987b3ef37721a886f720cdf4eb57dd71e9134999522...
# 889740  fae3606ed36408e9a244f62e02ad16d1fab93584f24626...
#
# [889741 rows x 3 columns]
# 627785

# %%
A = df[(df.label==1)].cano

B = df[(df.label==1)&df.cano.isin(A)].groupby('cano')['locdt']
BB = df[(df.label==0)&df.cano.isin(A)].groupby('cano')['locdt']


df[(df.label==1)].h_loctm.value_counts().sort_index().plot(kind='bar')
plt.show()

# df['mins_loctm'] =  (df.h_loctm*3600  + df.m_loctm*60 + df.s_loctm) /60
df[(df.label!=-1)&(df.cano.isin(A))].mins_loctm.plot(kind='hist',bins=48)
df[(df.label==1)].mins_loctm.plot(kind='hist',bins=48,color='red')

plt.show()


def IQR(x):
    return np.quantile(x,.75)-np.quantile(x,.25)

k=0
for x,y in B:
    k+=1
    print(f'---------{k}---------')
    print(x,y)
    if k==10:break
# Out:
#                                                      cano  counts  \
# 0       000004e90549c10a46912120949a36bbe9c92fb02daa27...       1
# 1       000004e90549c10a46912120949a36bbe9c92fb02daa27...       2
# 2       00002522901695edfbc8be6728ad6b5cd63f30a9a9b9c9...       1
# 3       00002522901695edfbc8be6728ad6b5cd63f30a9a9b9c9...       2
# 4       0000635e95f06e3542a664112f7dc9610e11ca4de383b1...       1
# ...                                                   ...     ...
# 889736  ffff8fed185e7a8295d6081fcac3a78cdd72d08903b95c...       1
# 889737  ffff8fed185e7a8295d6081fcac3a78cdd72d08903b95c...       2
# 889738  ffffa5b23e42f7b181116352663f282cd5e2f94a0bf5b6...       1
# 889739  ffffa5b23e42f7b181116352663f282cd5e2f94a0bf5b6...       2
# 889740  ffffa5b23e42f7b181116352663f282cd5e2f94a0bf5b6...       3
#
#                                                mode_mchno
# 0       09dd1fa2117349dc7fcbe7d88a8bbdab3eac610019010b...
# 1       c8131b6b345e94a8ff34642eae76ad4c71ce2027475ebc...
# 2       12c5b8c7cac508b0cf7214cee8c8ea9ebe1e23c5b0dd67...
# 3       216746c656372b82ca4960810749f3fd026977c793cebf...
# 4       e8d98e44151198526e079fdcc7f44c1e16be6f1fc2fb96...
# ...                                                   ...
# 889736  6c1fee0b78cb9da9ba0e4d3c91e75b3c195d66a974d9d6...
# 889737  9c18b9f9ea22011e9c30d284718fc42a4fa1272c356936...
# 889738  60a54fc232711d35dd53ae3c85afd669264bb97daee8a4...
# 889739  f9d987b3ef37721a886f720cdf4eb57dd71e9134999522...
# 889740  fae3606ed36408e9a244f62e02ad16d1fab93584f24626...
#
# [889741 rows x 3 columns]

# %% [markdown]
# ### 模型試跑

# %%
import lightgbm as lgb
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# 删除对象类型的列
training_data = training_data.drop(categorical_columns, axis=1)
public_data = public_data.drop(categorical_columns, axis=1)

# 分割特征和标签
X = training_data.drop(['txkey', 'label'], axis=1)
y = training_data['label']

# 使用SMOTE处理不平衡数据
smote = SMOTE(sampling_strategy=0.5, random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# 划分训练集和验证集
X_train, X_valid, y_train, y_valid = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# 定义LightGBM分类器
model = lgb.LGBMClassifier(objective='binary', random_state=42)

# 设置参数网格
param_grid = {
    'n_estimators': [500],  # 树的数量
    'max_depth': [4, 5],  # 树的深度
    'learning_rate': [0.1, 0.2],  # 学习率
    'min_child_weight': [1, 2],  # 叶子节点的最小权重和
    'subsample': [0.8],  # 用于训练每棵树的样本比例
    'colsample_bytree': [0.8],  # 每棵树的特征比例
    'reg_alpha': [0, 1],  # L1 正則化項
    'reg_lambda': [0, 1],  # L2 正則化項
    'scale_pos_weight': [len(y_train[y_train == 0]) / len(y_train[y_train == 1])]  # 添加scale_pos_weight
}

# 使用StratifiedKFold进行交叉验证
cv = StratifiedKFold(n_splits=4, shuffle=True, random_state=42)

# 创建GridSearchCV对象
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='f1', cv=cv, verbose=2, n_jobs=-1)

# 执行网格搜索
grid_search.fit(X_resampled, y_resampled)

# 输出最佳参数
best_params = grid_search.best_params_
print(f'Best Parameters: {best_params}')

# 获取最佳模型
best_model = grid_search.best_estimator_

# 训练最佳模型
best_model.fit(X_resampled, y_resampled)

# 预测验证集
y_pred = best_model.predict(X_valid)

# 评估模型
f1 = f1_score(y_valid, y_pred)

print(f'F1 Score on Validation Set: {f1}')

# 预测公共数据
X_public = public_data.drop('txkey', axis=1)
public_predictions = best_model.predict(X_public)
